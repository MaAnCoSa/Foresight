# %%
#Imports

import requests

# %%
#Constants
headers = {'Accept': 'application/json'}
base_url = url = "https://www.dnd5eapi.co"

spells_url = "/api/2014/spells"
monsters_url = "/api/2014/monsters"

# %%
#Functions

def fetch_data(url, header):
  response = requests.get(url, header)
  if response.status_code == 200:
    return response.json()

def process_items(data):
  print(f"We found {data['count']} items")
  for item in data['results']:
    print(f"{item['name']} - {item['url']}")

def process_monsters(data):
  print(f"We found {data['count']} items")
  for item in data['results']:
    monster = fetch_data(base_url + item['url'], headers)
    print(f"{item['name']} - HP: {monster['hit_points']} - CR: {monster['challenge_rating']}")
    for act in monster['actions']:
      if 'damage' in act: #filter out other actions and multi attack (include multi attack later)
        damage = ''
        i = 1
        for source in act['damage']:
          if 'choose' not in source:
            i += 1
            damage += f"{source['damage_dice']} {source['damage_type']['name']}"
            if len(act['damage']) > 1 and len(act['damage']) >= i:
              damage += ' plus '
        extra = ''
        if 'dc' in act:
          extra = f"DC: {act['dc']['dc_value']} {act['dc']['dc_type']['name']}"
        elif 'attack_bonus' in act:
          extra = f"+{act['attack_bonus']} to hit"
        else:
          extra = f'Conditional'
        print(f"-->{act['name']}: {extra}, {damage}")

# %%
# Print all monsters
monsters_data = fetch_data(base_url + monsters_url, headers)
process_items(monsters_data)
# Out:
# We found 334 items
# Aboleth - /api/2014/monsters/aboleth
# Acolyte - /api/2014/monsters/acolyte
# Adult Black Dragon - /api/2014/monsters/adult-black-dragon
# Adult Blue Dragon - /api/2014/monsters/adult-blue-dragon
# Adult Brass Dragon - /api/2014/monsters/adult-brass-dragon
# Adult Bronze Dragon - /api/2014/monsters/adult-bronze-dragon
# Adult Copper Dragon - /api/2014/monsters/adult-copper-dragon
# Adult Gold Dragon - /api/2014/monsters/adult-gold-dragon
# Adult Green Dragon - /api/2014/monsters/adult-green-dragon
# Adult Red Dragon - /api/2014/monsters/adult-red-dragon
# Adult Silver Dragon - /api/2014/monsters/adult-silver-dragon
# Adult White Dragon - /api/2014/monsters/adult-white-dragon
# Air Elemental - /api/2014/monsters/air-elemental
# Ancient Black Dragon - /api/2014/monsters/ancient-black-dragon
# Ancient Blue Dragon - /api/2014/monsters/ancient-blue-dragon
# Ancient Brass Dragon - /api/2014/monsters/ancient-brass-dragon
# Ancient Bronze Dragon - /api/2014/monsters/ancient-bronze-dragon
# Ancient Copper Dragon - /api/2014/monsters/ancient-copper-dragon
# Ancient Gold Dragon - /api/2014/monsters/ancient-gold-dragon
# Ancient Green Dragon - /api/2014/monsters/ancient-green-dragon
# Ancient Red Dragon - /api/2014/monsters/ancient-red-dragon
# Ancient Silver Dragon - /api/2014/monsters/ancient-silver-dragon
# Ancient White Dragon - /api/2014/monsters/ancient-white-dragon
# Androsphinx - /api/2014/monsters/androsphinx
# Animated Armor - /api/2014/monsters/animated-armor
# Ankheg - /api/2014/monsters/ankheg
# Ape - /api/2014/monsters/ape
# Archmage - /api/2014/monsters/archmage
# Assassin - /api/2014/monsters/assassin
# Awakened Shrub - /api/2014/monsters/awakened-shrub
# Awakened Tree - /api/2014/monsters/awakened-tree
# Axe Beak - /api/2014/monsters/axe-beak
# Azer - /api/2014/monsters/azer
# Baboon - /api/2014/monsters/baboon
# Badger - /api/2014/monsters/badger
# Balor - /api/2014/monsters/balor
# Bandit - /api/2014/monsters/bandit
# Bandit Captain - /api/2014/monsters/bandit-captain
# Barbed Devil - /api/2014/monsters/barbed-devil
# Basilisk - /api/2014/monsters/basilisk
# Bat - /api/2014/monsters/bat
# Bearded Devil - /api/2014/monsters/bearded-devil
# Behir - /api/2014/monsters/behir
# Berserker - /api/2014/monsters/berserker
# Black Bear - /api/2014/monsters/black-bear
# Black Dragon Wyrmling - /api/2014/monsters/black-dragon-wyrmling
# Black Pudding - /api/2014/monsters/black-pudding
# Blink Dog - /api/2014/monsters/blink-dog
# Blood Hawk - /api/2014/monsters/blood-hawk
# Blue Dragon Wyrmling - /api/2014/monsters/blue-dragon-wyrmling
# Boar - /api/2014/monsters/boar
# Bone Devil - /api/2014/monsters/bone-devil
# Brass Dragon Wyrmling - /api/2014/monsters/brass-dragon-wyrmling
# Bronze Dragon Wyrmling - /api/2014/monsters/bronze-dragon-wyrmling
# Brown Bear - /api/2014/monsters/brown-bear
# Bugbear - /api/2014/monsters/bugbear
# Bulette - /api/2014/monsters/bulette
# Camel - /api/2014/monsters/camel
# Cat - /api/2014/monsters/cat
# Centaur - /api/2014/monsters/centaur
# Chain Devil - /api/2014/monsters/chain-devil
# Chimera - /api/2014/monsters/chimera
# Chuul - /api/2014/monsters/chuul
# Clay Golem - /api/2014/monsters/clay-golem
# Cloaker - /api/2014/monsters/cloaker
# Cloud Giant - /api/2014/monsters/cloud-giant
# Cockatrice - /api/2014/monsters/cockatrice
# Commoner - /api/2014/monsters/commoner
# Constrictor Snake - /api/2014/monsters/constrictor-snake
# Copper Dragon Wyrmling - /api/2014/monsters/copper-dragon-wyrmling
# Couatl - /api/2014/monsters/couatl
# Crab - /api/2014/monsters/crab
# Crocodile - /api/2014/monsters/crocodile
# Cult Fanatic - /api/2014/monsters/cult-fanatic
# Cultist - /api/2014/monsters/cultist
# Darkmantle - /api/2014/monsters/darkmantle
# Death Dog - /api/2014/monsters/death-dog
# Deep Gnome (Svirfneblin) - /api/2014/monsters/deep-gnome-svirfneblin
# Deer - /api/2014/monsters/deer
# Deva - /api/2014/monsters/deva
# Dire Wolf - /api/2014/monsters/dire-wolf
# Djinni - /api/2014/monsters/djinni
# Doppelganger - /api/2014/monsters/doppelganger
# Draft Horse - /api/2014/monsters/draft-horse
# Dragon Turtle - /api/2014/monsters/dragon-turtle
# Dretch - /api/2014/monsters/dretch
# Drider - /api/2014/monsters/drider
# Drow - /api/2014/monsters/drow
# Druid - /api/2014/monsters/druid
# Dryad - /api/2014/monsters/dryad
# Duergar - /api/2014/monsters/duergar
# Dust Mephit - /api/2014/monsters/dust-mephit
# Eagle - /api/2014/monsters/eagle
# Earth Elemental - /api/2014/monsters/earth-elemental
# Efreeti - /api/2014/monsters/efreeti
# Elephant - /api/2014/monsters/elephant
# Elk - /api/2014/monsters/elk
# Erinyes - /api/2014/monsters/erinyes
# Ettercap - /api/2014/monsters/ettercap
# Ettin - /api/2014/monsters/ettin
# Fire Elemental - /api/2014/monsters/fire-elemental
# Fire Giant - /api/2014/monsters/fire-giant
# Flesh Golem - /api/2014/monsters/flesh-golem
# Flying Snake - /api/2014/monsters/flying-snake
# Flying Sword - /api/2014/monsters/flying-sword
# Frog - /api/2014/monsters/frog
# Frost Giant - /api/2014/monsters/frost-giant
# Gargoyle - /api/2014/monsters/gargoyle
# Gelatinous Cube - /api/2014/monsters/gelatinous-cube
# Ghast - /api/2014/monsters/ghast
# Ghost - /api/2014/monsters/ghost
# Ghoul - /api/2014/monsters/ghoul
# Giant Ape - /api/2014/monsters/giant-ape
# Giant Badger - /api/2014/monsters/giant-badger
# Giant Bat - /api/2014/monsters/giant-bat
# Giant Boar - /api/2014/monsters/giant-boar
# Giant Centipede - /api/2014/monsters/giant-centipede
# Giant Constrictor Snake - /api/2014/monsters/giant-constrictor-snake
# Giant Crab - /api/2014/monsters/giant-crab
# Giant Crocodile - /api/2014/monsters/giant-crocodile
# Giant Eagle - /api/2014/monsters/giant-eagle
# Giant Elk - /api/2014/monsters/giant-elk
# Giant Fire Beetle - /api/2014/monsters/giant-fire-beetle
# Giant Frog - /api/2014/monsters/giant-frog
# Giant Goat - /api/2014/monsters/giant-goat
# Giant Hyena - /api/2014/monsters/giant-hyena
# Giant Lizard - /api/2014/monsters/giant-lizard
# Giant Octopus - /api/2014/monsters/giant-octopus
# Giant Owl - /api/2014/monsters/giant-owl
# Giant Poisonous Snake - /api/2014/monsters/giant-poisonous-snake
# Giant Rat - /api/2014/monsters/giant-rat
# Giant Rat (Diseased) - /api/2014/monsters/giant-rat-diseased
# Giant Scorpion - /api/2014/monsters/giant-scorpion
# Giant Sea Horse - /api/2014/monsters/giant-sea-horse
# Giant Shark - /api/2014/monsters/giant-shark
# Giant Spider - /api/2014/monsters/giant-spider
# Giant Toad - /api/2014/monsters/giant-toad
# Giant Vulture - /api/2014/monsters/giant-vulture
# Giant Wasp - /api/2014/monsters/giant-wasp
# Giant Weasel - /api/2014/monsters/giant-weasel
# Giant Wolf Spider - /api/2014/monsters/giant-wolf-spider
# Gibbering Mouther - /api/2014/monsters/gibbering-mouther
# Glabrezu - /api/2014/monsters/glabrezu
# Gladiator - /api/2014/monsters/gladiator
# Gnoll - /api/2014/monsters/gnoll
# Goat - /api/2014/monsters/goat
# Goblin - /api/2014/monsters/goblin
# Gold Dragon Wyrmling - /api/2014/monsters/gold-dragon-wyrmling
# Gorgon - /api/2014/monsters/gorgon
# Gray Ooze - /api/2014/monsters/gray-ooze
# Green Dragon Wyrmling - /api/2014/monsters/green-dragon-wyrmling
# Green Hag - /api/2014/monsters/green-hag
# Grick - /api/2014/monsters/grick
# Griffon - /api/2014/monsters/griffon
# Grimlock - /api/2014/monsters/grimlock
# Guard - /api/2014/monsters/guard
# Guardian Naga - /api/2014/monsters/guardian-naga
# Gynosphinx - /api/2014/monsters/gynosphinx
# Half-Red Dragon Veteran - /api/2014/monsters/half-red-dragon-veteran
# Harpy - /api/2014/monsters/harpy
# Hawk - /api/2014/monsters/hawk
# Hell Hound - /api/2014/monsters/hell-hound
# Hezrou - /api/2014/monsters/hezrou
# Hill Giant - /api/2014/monsters/hill-giant
# Hippogriff - /api/2014/monsters/hippogriff
# Hobgoblin - /api/2014/monsters/hobgoblin
# Homunculus - /api/2014/monsters/homunculus
# Horned Devil - /api/2014/monsters/horned-devil
# Hunter Shark - /api/2014/monsters/hunter-shark
# Hydra - /api/2014/monsters/hydra
# Hyena - /api/2014/monsters/hyena
# Ice Devil - /api/2014/monsters/ice-devil
# Ice Mephit - /api/2014/monsters/ice-mephit
# Imp - /api/2014/monsters/imp
# Invisible Stalker - /api/2014/monsters/invisible-stalker
# Iron Golem - /api/2014/monsters/iron-golem
# Jackal - /api/2014/monsters/jackal
# Killer Whale - /api/2014/monsters/killer-whale
# Knight - /api/2014/monsters/knight
# Kobold - /api/2014/monsters/kobold
# Kraken - /api/2014/monsters/kraken
# Lamia - /api/2014/monsters/lamia
# Lemure - /api/2014/monsters/lemure
# Lich - /api/2014/monsters/lich
# Lion - /api/2014/monsters/lion
# Lizard - /api/2014/monsters/lizard
# Lizardfolk - /api/2014/monsters/lizardfolk
# Mage - /api/2014/monsters/mage
# Magma Mephit - /api/2014/monsters/magma-mephit
# Magmin - /api/2014/monsters/magmin
# Mammoth - /api/2014/monsters/mammoth
# Manticore - /api/2014/monsters/manticore
# Marilith - /api/2014/monsters/marilith
# Mastiff - /api/2014/monsters/mastiff
# Medusa - /api/2014/monsters/medusa
# Merfolk - /api/2014/monsters/merfolk
# Merrow - /api/2014/monsters/merrow
# Mimic - /api/2014/monsters/mimic
# Minotaur - /api/2014/monsters/minotaur
# Minotaur Skeleton - /api/2014/monsters/minotaur-skeleton
# Mule - /api/2014/monsters/mule
# Mummy - /api/2014/monsters/mummy
# Mummy Lord - /api/2014/monsters/mummy-lord
# Nalfeshnee - /api/2014/monsters/nalfeshnee
# Night Hag - /api/2014/monsters/night-hag
# Nightmare - /api/2014/monsters/nightmare
# Noble - /api/2014/monsters/noble
# Ochre Jelly - /api/2014/monsters/ochre-jelly
# Octopus - /api/2014/monsters/octopus
# Ogre - /api/2014/monsters/ogre
# Ogre Zombie - /api/2014/monsters/ogre-zombie
# Oni - /api/2014/monsters/oni
# Orc - /api/2014/monsters/orc
# Otyugh - /api/2014/monsters/otyugh
# Owl - /api/2014/monsters/owl
# Owlbear - /api/2014/monsters/owlbear
# Panther - /api/2014/monsters/panther
# Pegasus - /api/2014/monsters/pegasus
# Phase Spider - /api/2014/monsters/phase-spider
# Pit Fiend - /api/2014/monsters/pit-fiend
# Planetar - /api/2014/monsters/planetar
# Plesiosaurus - /api/2014/monsters/plesiosaurus
# Poisonous Snake - /api/2014/monsters/poisonous-snake
# Polar Bear - /api/2014/monsters/polar-bear
# Pony - /api/2014/monsters/pony
# Priest - /api/2014/monsters/priest
# Pseudodragon - /api/2014/monsters/pseudodragon
# Purple Worm - /api/2014/monsters/purple-worm
# Quasit - /api/2014/monsters/quasit
# Quipper - /api/2014/monsters/quipper
# Rakshasa - /api/2014/monsters/rakshasa
# Rat - /api/2014/monsters/rat
# Raven - /api/2014/monsters/raven
# Red Dragon Wyrmling - /api/2014/monsters/red-dragon-wyrmling
# Reef Shark - /api/2014/monsters/reef-shark
# Remorhaz - /api/2014/monsters/remorhaz
# Rhinoceros - /api/2014/monsters/rhinoceros
# Riding Horse - /api/2014/monsters/riding-horse
# Roc - /api/2014/monsters/roc
# Roper - /api/2014/monsters/roper
# Rug of Smothering - /api/2014/monsters/rug-of-smothering
# Rust Monster - /api/2014/monsters/rust-monster
# Saber-Toothed Tiger - /api/2014/monsters/saber-toothed-tiger
# Sahuagin - /api/2014/monsters/sahuagin
# Salamander - /api/2014/monsters/salamander
# Satyr - /api/2014/monsters/satyr
# Scorpion - /api/2014/monsters/scorpion
# Scout - /api/2014/monsters/scout
# Sea Hag - /api/2014/monsters/sea-hag
# Sea Horse - /api/2014/monsters/sea-horse
# Shadow - /api/2014/monsters/shadow
# Shambling Mound - /api/2014/monsters/shambling-mound
# Shield Guardian - /api/2014/monsters/shield-guardian
# Shrieker - /api/2014/monsters/shrieker
# Silver Dragon Wyrmling - /api/2014/monsters/silver-dragon-wyrmling
# Skeleton - /api/2014/monsters/skeleton
# Solar - /api/2014/monsters/solar
# Specter - /api/2014/monsters/specter
# Spider - /api/2014/monsters/spider
# Spirit Naga - /api/2014/monsters/spirit-naga
# Sprite - /api/2014/monsters/sprite
# Spy - /api/2014/monsters/spy
# Steam Mephit - /api/2014/monsters/steam-mephit
# Stirge - /api/2014/monsters/stirge
# Stone Giant - /api/2014/monsters/stone-giant
# Stone Golem - /api/2014/monsters/stone-golem
# Storm Giant - /api/2014/monsters/storm-giant
# Succubus/Incubus - /api/2014/monsters/succubus-incubus
# Swarm of Bats - /api/2014/monsters/swarm-of-bats
# Swarm of Beetles - /api/2014/monsters/swarm-of-beetles
# Swarm of Centipedes - /api/2014/monsters/swarm-of-centipedes
# Swarm of Insects - /api/2014/monsters/swarm-of-insects
# Swarm of Poisonous Snakes - /api/2014/monsters/swarm-of-poisonous-snakes
# Swarm of Quippers - /api/2014/monsters/swarm-of-quippers
# Swarm of Rats - /api/2014/monsters/swarm-of-rats
# Swarm of Ravens - /api/2014/monsters/swarm-of-ravens
# Swarm of Spiders - /api/2014/monsters/swarm-of-spiders
# Swarm of Wasps - /api/2014/monsters/swarm-of-wasps
# Tarrasque - /api/2014/monsters/tarrasque
# Thug - /api/2014/monsters/thug
# Tiger - /api/2014/monsters/tiger
# Treant - /api/2014/monsters/treant
# Tribal Warrior - /api/2014/monsters/tribal-warrior
# Triceratops - /api/2014/monsters/triceratops
# Troll - /api/2014/monsters/troll
# Tyrannosaurus Rex - /api/2014/monsters/tyrannosaurus-rex
# Unicorn - /api/2014/monsters/unicorn
# Vampire, Bat Form - /api/2014/monsters/vampire-bat
# Vampire, Mist Form - /api/2014/monsters/vampire-mist
# Vampire Spawn - /api/2014/monsters/vampire-spawn
# Vampire, Vampire Form - /api/2014/monsters/vampire-vampire
# Veteran - /api/2014/monsters/veteran
# Violet Fungus - /api/2014/monsters/violet-fungus
# Vrock - /api/2014/monsters/vrock
# Vulture - /api/2014/monsters/vulture
# Warhorse - /api/2014/monsters/warhorse
# Warhorse Skeleton - /api/2014/monsters/warhorse-skeleton
# Water Elemental - /api/2014/monsters/water-elemental
# Weasel - /api/2014/monsters/weasel
# Werebear, Bear Form - /api/2014/monsters/werebear-bear
# Werebear, Human Form - /api/2014/monsters/werebear-human
# Werebear, Hybrid Form - /api/2014/monsters/werebear-hybrid
# Wereboar, Boar Form - /api/2014/monsters/wereboar-boar
# Wereboar, Human Form - /api/2014/monsters/wereboar-human
# Wereboar, Hybrid Form - /api/2014/monsters/wereboar-hybrid
# Wererat, Human Form - /api/2014/monsters/wererat-human
# Wererat, Hybrid Form - /api/2014/monsters/wererat-hybrid
# Wererat, Rat Form - /api/2014/monsters/wererat-rat
# Weretiger, Human Form - /api/2014/monsters/weretiger-human
# Weretiger, Hybrid Form - /api/2014/monsters/weretiger-hybrid
# Weretiger, Tiger Form - /api/2014/monsters/weretiger-tiger
# Werewolf, Human Form - /api/2014/monsters/werewolf-human
# Werewolf, Hybrid Form - /api/2014/monsters/werewolf-hybrid
# Werewolf, Wolf Form - /api/2014/monsters/werewolf-wolf
# White Dragon Wyrmling - /api/2014/monsters/white-dragon-wyrmling
# Wight - /api/2014/monsters/wight
# Will-o'-Wisp - /api/2014/monsters/will-o-wisp
# Winter Wolf - /api/2014/monsters/winter-wolf
# Wolf - /api/2014/monsters/wolf
# Worg - /api/2014/monsters/worg
# Wraith - /api/2014/monsters/wraith
# Wyvern - /api/2014/monsters/wyvern
# Xorn - /api/2014/monsters/xorn
# Young Black Dragon - /api/2014/monsters/young-black-dragon
# Young Blue Dragon - /api/2014/monsters/young-blue-dragon
# Young Brass Dragon - /api/2014/monsters/young-brass-dragon
# Young Bronze Dragon - /api/2014/monsters/young-bronze-dragon
# Young Copper Dragon - /api/2014/monsters/young-copper-dragon
# Young Gold Dragon - /api/2014/monsters/young-gold-dragon
# Young Green Dragon - /api/2014/monsters/young-green-dragon
# Young Red Dragon - /api/2014/monsters/young-red-dragon
# Young Silver Dragon - /api/2014/monsters/young-silver-dragon
# Young White Dragon - /api/2014/monsters/young-white-dragon
# Zombie - /api/2014/monsters/zombie

# %%
# Get all spells data
spells_data = fetch_data(base_url + spells_url, headers)
process_items(spells_data)
# Out:
# We found 319 items
# Acid Arrow - /api/2014/spells/acid-arrow
# Acid Splash - /api/2014/spells/acid-splash
# Aid - /api/2014/spells/aid
# Alarm - /api/2014/spells/alarm
# Alter Self - /api/2014/spells/alter-self
# Animal Friendship - /api/2014/spells/animal-friendship
# Animal Messenger - /api/2014/spells/animal-messenger
# Animal Shapes - /api/2014/spells/animal-shapes
# Animate Dead - /api/2014/spells/animate-dead
# Animate Objects - /api/2014/spells/animate-objects
# Antilife Shell - /api/2014/spells/antilife-shell
# Antimagic Field - /api/2014/spells/antimagic-field
# Antipathy/Sympathy - /api/2014/spells/antipathy-sympathy
# Arcane Eye - /api/2014/spells/arcane-eye
# Arcane Hand - /api/2014/spells/arcane-hand
# Arcane Lock - /api/2014/spells/arcane-lock
# Arcane Sword - /api/2014/spells/arcane-sword
# Arcanist's Magic Aura - /api/2014/spells/arcanists-magic-aura
# Astral Projection - /api/2014/spells/astral-projection
# Augury - /api/2014/spells/augury
# Awaken - /api/2014/spells/awaken
# Bane - /api/2014/spells/bane
# Banishment - /api/2014/spells/banishment
# Barkskin - /api/2014/spells/barkskin
# Beacon of Hope - /api/2014/spells/beacon-of-hope
# Bestow Curse - /api/2014/spells/bestow-curse
# Black Tentacles - /api/2014/spells/black-tentacles
# Blade Barrier - /api/2014/spells/blade-barrier
# Bless - /api/2014/spells/bless
# Blight - /api/2014/spells/blight
# Blindness/Deafness - /api/2014/spells/blindness-deafness
# Blink - /api/2014/spells/blink
# Blur - /api/2014/spells/blur
# Branding Smite - /api/2014/spells/branding-smite
# Burning Hands - /api/2014/spells/burning-hands
# Call Lightning - /api/2014/spells/call-lightning
# Calm Emotions - /api/2014/spells/calm-emotions
# Chain Lightning - /api/2014/spells/chain-lightning
# Charm Person - /api/2014/spells/charm-person
# Chill Touch - /api/2014/spells/chill-touch
# Circle of Death - /api/2014/spells/circle-of-death
# Clairvoyance - /api/2014/spells/clairvoyance
# Clone - /api/2014/spells/clone
# Cloudkill - /api/2014/spells/cloudkill
# Color Spray - /api/2014/spells/color-spray
# Command - /api/2014/spells/command
# Commune - /api/2014/spells/commune
# Commune With Nature - /api/2014/spells/commune-with-nature
# Comprehend Languages - /api/2014/spells/comprehend-languages
# Compulsion - /api/2014/spells/compulsion
# Cone of Cold - /api/2014/spells/cone-of-cold
# Confusion - /api/2014/spells/confusion
# Conjure Animals - /api/2014/spells/conjure-animals
# Conjure Celestial - /api/2014/spells/conjure-celestial
# Conjure Elemental - /api/2014/spells/conjure-elemental
# Conjure Fey - /api/2014/spells/conjure-fey
# Conjure Minor Elementals - /api/2014/spells/conjure-minor-elementals
# Conjure Woodland Beings - /api/2014/spells/conjure-woodland-beings
# Contact Other Plane - /api/2014/spells/contact-other-plane
# Contagion - /api/2014/spells/contagion
# Contingency - /api/2014/spells/contingency
# Continual Flame - /api/2014/spells/continual-flame
# Control Water - /api/2014/spells/control-water
# Control Weather - /api/2014/spells/control-weather
# Counterspell - /api/2014/spells/counterspell
# Create Food and Water - /api/2014/spells/create-food-and-water
# Create or Destroy Water - /api/2014/spells/create-or-destroy-water
# Create Undead - /api/2014/spells/create-undead
# Creation - /api/2014/spells/creation
# Cure Wounds - /api/2014/spells/cure-wounds
# Dancing Lights - /api/2014/spells/dancing-lights
# Darkness - /api/2014/spells/darkness
# Darkvision - /api/2014/spells/darkvision
# Daylight - /api/2014/spells/daylight
# Death Ward - /api/2014/spells/death-ward
# Delayed Blast Fireball - /api/2014/spells/delayed-blast-fireball
# Demiplane - /api/2014/spells/demiplane
# Detect Evil and Good - /api/2014/spells/detect-evil-and-good
# Detect Magic - /api/2014/spells/detect-magic
# Detect Poison and Disease - /api/2014/spells/detect-poison-and-disease
# Detect Thoughts - /api/2014/spells/detect-thoughts
# Dimension Door - /api/2014/spells/dimension-door
# Disguise Self - /api/2014/spells/disguise-self
# Disintegrate - /api/2014/spells/disintegrate
# Dispel Evil and Good - /api/2014/spells/dispel-evil-and-good
# Dispel Magic - /api/2014/spells/dispel-magic
# Divination - /api/2014/spells/divination
# Divine Favor - /api/2014/spells/divine-favor
# Divine Word - /api/2014/spells/divine-word
# Dominate Beast - /api/2014/spells/dominate-beast
# Dominate Monster - /api/2014/spells/dominate-monster
# Dominate Person - /api/2014/spells/dominate-person
# Dream - /api/2014/spells/dream
# Druidcraft - /api/2014/spells/druidcraft
# Earthquake - /api/2014/spells/earthquake
# Eldritch Blast - /api/2014/spells/eldritch-blast
# Enhance Ability - /api/2014/spells/enhance-ability
# Enlarge/Reduce - /api/2014/spells/enlarge-reduce
# Entangle - /api/2014/spells/entangle
# Enthrall - /api/2014/spells/enthrall
# Etherealness - /api/2014/spells/etherealness
# Expeditious Retreat - /api/2014/spells/expeditious-retreat
# Eyebite - /api/2014/spells/eyebite
# Fabricate - /api/2014/spells/fabricate
# Faerie Fire - /api/2014/spells/faerie-fire
# Faithful Hound - /api/2014/spells/faithful-hound
# False Life - /api/2014/spells/false-life
# Fear - /api/2014/spells/fear
# Feather Fall - /api/2014/spells/feather-fall
# Feeblemind - /api/2014/spells/feeblemind
# Find Familiar - /api/2014/spells/find-familiar
# Find Steed - /api/2014/spells/find-steed
# Find the Path - /api/2014/spells/find-the-path
# Find Traps - /api/2014/spells/find-traps
# Finger of Death - /api/2014/spells/finger-of-death
# Fire Bolt - /api/2014/spells/fire-bolt
# Fire Shield - /api/2014/spells/fire-shield
# Fire Storm - /api/2014/spells/fire-storm
# Fireball - /api/2014/spells/fireball
# Flame Blade - /api/2014/spells/flame-blade
# Flame Strike - /api/2014/spells/flame-strike
# Flaming Sphere - /api/2014/spells/flaming-sphere
# Flesh to Stone - /api/2014/spells/flesh-to-stone
# Floating Disk - /api/2014/spells/floating-disk
# Fly - /api/2014/spells/fly
# Fog Cloud - /api/2014/spells/fog-cloud
# Forbiddance - /api/2014/spells/forbiddance
# Forcecage - /api/2014/spells/forcecage
# Foresight - /api/2014/spells/foresight
# Freedom of Movement - /api/2014/spells/freedom-of-movement
# Freezing Sphere - /api/2014/spells/freezing-sphere
# Gaseous Form - /api/2014/spells/gaseous-form
# Gate - /api/2014/spells/gate
# Geas - /api/2014/spells/geas
# Gentle Repose - /api/2014/spells/gentle-repose
# Giant Insect - /api/2014/spells/giant-insect
# Glibness - /api/2014/spells/glibness
# Globe of Invulnerability - /api/2014/spells/globe-of-invulnerability
# Glyph of Warding - /api/2014/spells/glyph-of-warding
# Goodberry - /api/2014/spells/goodberry
# Grease - /api/2014/spells/grease
# Greater Invisibility - /api/2014/spells/greater-invisibility
# Greater Restoration - /api/2014/spells/greater-restoration
# Guardian of Faith - /api/2014/spells/guardian-of-faith
# Guards and Wards - /api/2014/spells/guards-and-wards
# Guidance - /api/2014/spells/guidance
# Guiding Bolt - /api/2014/spells/guiding-bolt
# Gust of Wind - /api/2014/spells/gust-of-wind
# Hallow - /api/2014/spells/hallow
# Hallucinatory Terrain - /api/2014/spells/hallucinatory-terrain
# Harm - /api/2014/spells/harm
# Haste - /api/2014/spells/haste
# Heal - /api/2014/spells/heal
# Healing Word - /api/2014/spells/healing-word
# Heat Metal - /api/2014/spells/heat-metal
# Hellish Rebuke - /api/2014/spells/hellish-rebuke
# Heroes' Feast - /api/2014/spells/heroes-feast
# Heroism - /api/2014/spells/heroism
# Hideous Laughter - /api/2014/spells/hideous-laughter
# Hold Monster - /api/2014/spells/hold-monster
# Hold Person - /api/2014/spells/hold-person
# Holy Aura - /api/2014/spells/holy-aura
# Hunter's Mark - /api/2014/spells/hunters-mark
# Hypnotic Pattern - /api/2014/spells/hypnotic-pattern
# Ice Storm - /api/2014/spells/ice-storm
# Identify - /api/2014/spells/identify
# Illusory Script - /api/2014/spells/illusory-script
# Imprisonment - /api/2014/spells/imprisonment
# Incendiary Cloud - /api/2014/spells/incendiary-cloud
# Inflict Wounds - /api/2014/spells/inflict-wounds
# Insect Plague - /api/2014/spells/insect-plague
# Instant Summons - /api/2014/spells/instant-summons
# Invisibility - /api/2014/spells/invisibility
# Irresistible Dance - /api/2014/spells/irresistible-dance
# Jump - /api/2014/spells/jump
# Knock - /api/2014/spells/knock
# Legend Lore - /api/2014/spells/legend-lore
# Lesser Restoration - /api/2014/spells/lesser-restoration
# Levitate - /api/2014/spells/levitate
# Light - /api/2014/spells/light
# Lightning Bolt - /api/2014/spells/lightning-bolt
# Locate Animals or Plants - /api/2014/spells/locate-animals-or-plants
# Locate Creature - /api/2014/spells/locate-creature
# Locate Object - /api/2014/spells/locate-object
# Longstrider - /api/2014/spells/longstrider
# Mage Armor - /api/2014/spells/mage-armor
# Mage Hand - /api/2014/spells/mage-hand
# Magic Circle - /api/2014/spells/magic-circle
# Magic Jar - /api/2014/spells/magic-jar
# Magic Missile - /api/2014/spells/magic-missile
# Magic Mouth - /api/2014/spells/magic-mouth
# Magic Weapon - /api/2014/spells/magic-weapon
# Magnificent Mansion - /api/2014/spells/magnificent-mansion
# Major Image - /api/2014/spells/major-image
# Mass Cure Wounds - /api/2014/spells/mass-cure-wounds
# Mass Heal - /api/2014/spells/mass-heal
# Mass Healing Word - /api/2014/spells/mass-healing-word
# Mass Suggestion - /api/2014/spells/mass-suggestion
# Maze - /api/2014/spells/maze
# Meld Into Stone - /api/2014/spells/meld-into-stone
# Mending - /api/2014/spells/mending
# Message - /api/2014/spells/message
# Meteor Swarm - /api/2014/spells/meteor-swarm
# Mind Blank - /api/2014/spells/mind-blank
# Minor Illusion - /api/2014/spells/minor-illusion
# Mirage Arcane - /api/2014/spells/mirage-arcane
# Mirror Image - /api/2014/spells/mirror-image
# Mislead - /api/2014/spells/mislead
# Misty Step - /api/2014/spells/misty-step
# Modify Memory - /api/2014/spells/modify-memory
# Moonbeam - /api/2014/spells/moonbeam
# Move Earth - /api/2014/spells/move-earth
# Nondetection - /api/2014/spells/nondetection
# Pass Without Trace - /api/2014/spells/pass-without-trace
# Passwall - /api/2014/spells/passwall
# Phantasmal Killer - /api/2014/spells/phantasmal-killer
# Phantom Steed - /api/2014/spells/phantom-steed
# Planar Ally - /api/2014/spells/planar-ally
# Planar Binding - /api/2014/spells/planar-binding
# Plane Shift - /api/2014/spells/plane-shift
# Plant Growth - /api/2014/spells/plant-growth
# Poison Spray - /api/2014/spells/poison-spray
# Polymorph - /api/2014/spells/polymorph
# Power Word Kill - /api/2014/spells/power-word-kill
# Power Word Stun - /api/2014/spells/power-word-stun
# Prayer of Healing - /api/2014/spells/prayer-of-healing
# Prestidigitation - /api/2014/spells/prestidigitation
# Prismatic Spray - /api/2014/spells/prismatic-spray
# Prismatic Wall - /api/2014/spells/prismatic-wall
# Private Sanctum - /api/2014/spells/private-sanctum
# Produce Flame - /api/2014/spells/produce-flame
# Programmed Illusion - /api/2014/spells/programmed-illusion
# Project Image - /api/2014/spells/project-image
# Protection From Energy - /api/2014/spells/protection-from-energy
# Protection from Evil and Good - /api/2014/spells/protection-from-evil-and-good
# Protection from Poison - /api/2014/spells/protection-from-poison
# Purify Food and Drink - /api/2014/spells/purify-food-and-drink
# Raise Dead - /api/2014/spells/raise-dead
# Ray of Enfeeblement - /api/2014/spells/ray-of-enfeeblement
# Ray of Frost - /api/2014/spells/ray-of-frost
# Regenerate - /api/2014/spells/regenerate
# Reincarnate - /api/2014/spells/reincarnate
# Remove Curse - /api/2014/spells/remove-curse
# Resilient Sphere - /api/2014/spells/resilient-sphere
# Resistance - /api/2014/spells/resistance
# Resurrection - /api/2014/spells/resurrection
# Reverse Gravity - /api/2014/spells/reverse-gravity
# Revivify - /api/2014/spells/revivify
# Rope Trick - /api/2014/spells/rope-trick
# Sacred Flame - /api/2014/spells/sacred-flame
# Sanctuary - /api/2014/spells/sanctuary
# Scorching Ray - /api/2014/spells/scorching-ray
# Scrying - /api/2014/spells/scrying
# Secret Chest - /api/2014/spells/secret-chest
# See Invisibility - /api/2014/spells/see-invisibility
# Seeming - /api/2014/spells/seeming
# Sending - /api/2014/spells/sending
# Sequester - /api/2014/spells/sequester
# Shapechange - /api/2014/spells/shapechange
# Shatter - /api/2014/spells/shatter
# Shield - /api/2014/spells/shield
# Shield of Faith - /api/2014/spells/shield-of-faith
# Shillelagh - /api/2014/spells/shillelagh
# Shocking Grasp - /api/2014/spells/shocking-grasp
# Silence - /api/2014/spells/silence
# Silent Image - /api/2014/spells/silent-image
# Simulacrum - /api/2014/spells/simulacrum
# Sleep - /api/2014/spells/sleep
# Sleet Storm - /api/2014/spells/sleet-storm
# Slow - /api/2014/spells/slow
# Spare the Dying - /api/2014/spells/spare-the-dying
# Speak with Animals - /api/2014/spells/speak-with-animals
# Speak with Dead - /api/2014/spells/speak-with-dead
# Speak with Plants - /api/2014/spells/speak-with-plants
# Spider Climb - /api/2014/spells/spider-climb
# Spike Growth - /api/2014/spells/spike-growth
# Spirit Guardians - /api/2014/spells/spirit-guardians
# Spiritual Weapon - /api/2014/spells/spiritual-weapon
# Stinking Cloud - /api/2014/spells/stinking-cloud
# Stone Shape - /api/2014/spells/stone-shape
# Stoneskin - /api/2014/spells/stoneskin
# Storm of Vengeance - /api/2014/spells/storm-of-vengeance
# Suggestion - /api/2014/spells/suggestion
# Sunbeam - /api/2014/spells/sunbeam
# Sunburst - /api/2014/spells/sunburst
# Symbol - /api/2014/spells/symbol
# Telekinesis - /api/2014/spells/telekinesis
# Telepathic Bond - /api/2014/spells/telepathic-bond
# Teleport - /api/2014/spells/teleport
# Teleportation Circle - /api/2014/spells/teleportation-circle
# Thaumaturgy - /api/2014/spells/thaumaturgy
# Thunderwave - /api/2014/spells/thunderwave
# Time Stop - /api/2014/spells/time-stop
# Tiny Hut - /api/2014/spells/tiny-hut
# Tongues - /api/2014/spells/tongues
# Transport via Plants - /api/2014/spells/transport-via-plants
# Tree Stride - /api/2014/spells/tree-stride
# True Polymorph - /api/2014/spells/true-polymorph
# True Resurrection - /api/2014/spells/true-resurrection
# True Seeing - /api/2014/spells/true-seeing
# True Strike - /api/2014/spells/true-strike
# Unseen Servant - /api/2014/spells/unseen-servant
# Vampiric Touch - /api/2014/spells/vampiric-touch
# Vicious Mockery - /api/2014/spells/vicious-mockery
# Wall of Fire - /api/2014/spells/wall-of-fire
# Wall of Force - /api/2014/spells/wall-of-force
# Wall of Ice - /api/2014/spells/wall-of-ice
# Wall of Stone - /api/2014/spells/wall-of-stone
# Wall of Thorns - /api/2014/spells/wall-of-thorns
# Warding Bond - /api/2014/spells/warding-bond
# Water Breathing - /api/2014/spells/water-breathing
# Water Walk - /api/2014/spells/water-walk
# Web - /api/2014/spells/web
# Weird - /api/2014/spells/weird
# Wind Walk - /api/2014/spells/wind-walk
# Wind Wall - /api/2014/spells/wind-wall
# Wish - /api/2014/spells/wish
# Word of Recall - /api/2014/spells/word-of-recall
# Zone of Truth - /api/2014/spells/zone-of-truth

# %%
monsters_data = fetch_data(base_url + monsters_url, headers)
process_monsters(monsters_data)
# Out:
# We found 334 items
# Aboleth - HP: 135 - CR: 10
# -->Tentacle: DC: 14 CON, 2d6+5 Bludgeoning plus 1d12 Acid
# -->Tail: +9 to hit, 3d6+5 Bludgeoning
# Acolyte - HP: 9 - CR: 0.25
# -->Club: +2 to hit, 1d4 Bludgeoning
# Adult Black Dragon - HP: 195 - CR: 14
# -->Bite: +11 to hit, 2d10+6 Piercing plus 1d8 Acid
# -->Claw: +11 to hit, 2d6+6 Slashing
# -->Tail: +11 to hit, 2d8+6 Bludgeoning
# -->Acid Breath: DC: 18 DEX, 12d8 Acid
# Adult Blue Dragon - HP: 225 - CR: 16
# -->Bite: +12 to hit, 2d10+7 Piercing plus 1d10 Lightning
# -->Claw: +12 to hit, 2d6+7 Slashing
# -->Tail: +12 to hit, 2d8+7 Bludgeoning
# -->Lightning Breath: DC: 19 DEX, 12d10 Lightning
# Adult Brass Dragon - HP: 172 - CR: 13
# -->Bite: +11 to hit, 2d10+6 Piercing
# -->Claw: +11 to hit, 2d6+6 Slashing
# -->Tail: +11 to hit, 2d8+6 Bludgeoning
# Adult Bronze Dragon - HP: 212 - CR: 15
# -->Bite: +12 to hit, 2d10+7 Piercing
# -->Claw: +12 to hit, 2d6+7 Slashing
# -->Tail: +12 to hit, 2d8+7 Bludgeoning
# Adult Copper Dragon - HP: 184 - CR: 14
# -->Bite: +11 to hit, 2d10+6 Piercing
# -->Claw: +11 to hit, 2d6+6 Slashing
# -->Tail: +11 to hit, 2d8+6 Bludgeoning
# Adult Gold Dragon - HP: 256 - CR: 17
# -->Bite: +14 to hit, 2d10+8 Piercing
# -->Claw: +14 to hit, 2d6+8 Slashing
# -->Tail: +14 to hit, 2d8+8 Bludgeoning
# Adult Green Dragon - HP: 207 - CR: 15
# -->Bite: +11 to hit, 2d10+6 Piercing plus 2d6 Poison
# -->Claw: +11 to hit, 2d6+6 Slashing
# -->Tail: +11 to hit, 2d8+6 Bludgeoning
# -->Poison Breath: DC: 18 CON, 16d6 Poison
# Adult Red Dragon - HP: 256 - CR: 17
# -->Bite: +14 to hit, 2d10+8 Piercing plus 2d6 Fire
# -->Claw: +14 to hit, 2d6+8 Slashing
# -->Tail: +14 to hit, 2d8+8 Bludgeoning
# -->Fire Breath: DC: 21 DEX, 18d6 Fire
# Adult Silver Dragon - HP: 243 - CR: 16
# -->Bite: +13 to hit, 2d10+8 Piercing
# -->Claw: +13 to hit, 2d6+8 Slashing
# -->Tail: +13 to hit, 2d8+8 Bludgeoning
# Adult White Dragon - HP: 200 - CR: 13
# -->Bite: +11 to hit, 2d10+6 Piercing plus 1d8 Cold
# -->Claw: +11 to hit, 2d6+6 Slashing
# -->Tail: +11 to hit, 2d8+6 Bludgeoning
# -->Cold Breath: DC: 19 CON, 12d8 Cold
# Air Elemental - HP: 90 - CR: 5
# -->Slam: +8 to hit, 2d8+5 Bludgeoning
# Ancient Black Dragon - HP: 367 - CR: 21
# -->Bite: +15 to hit, 2d10+8 Piercing plus 2d8 Acid
# -->Claw: +15 to hit, 2d6+8 Slashing
# -->Tail: +15 to hit, 2d8+8 Bludgeoning
# -->Acid Breath: DC: 22 DEX, 15d8 Acid
# Ancient Blue Dragon - HP: 481 - CR: 23
# -->Bite: +16 to hit, 2d10+9 Piercing plus 2d10 Lightning
# -->Claw: +16 to hit, 2d6+9 Slashing
# -->Tail: +16 to hit, 2d8+9 Bludgeoning
# -->Lightning Breath: DC: 23 DEX, 16d10 Lightning
# Ancient Brass Dragon - HP: 297 - CR: 20
# -->Bite: +14 to hit, 2d10+8 Piercing
# -->Claw: +14 to hit, 2d6+8 Slashing
# -->Tail: +14 to hit, 2d8+8 Bludgeoning
# Ancient Bronze Dragon - HP: 444 - CR: 22
# -->Bite: +16 to hit, 2d10+9 Piercing
# -->Claw: +16 to hit, 2d6+9 Slashing
# -->Tail: +16 to hit, 2d8+9 Bludgeoning
# Ancient Copper Dragon - HP: 350 - CR: 21
# -->Bite: +15 to hit, 2d10+8 Piercing
# -->Claw: +15 to hit, 2d6+8 Slashing
# -->Tail: +15 to hit, 2d8+8 Bludgeoning
# Ancient Gold Dragon - HP: 546 - CR: 24
# -->Bite: +17 to hit, 2d10+10 Piercing
# -->Claw: +17 to hit, 2d6+10 Slashing
# -->Tail: +17 to hit, 2d8+10 Bludgeoning
# Ancient Green Dragon - HP: 385 - CR: 22
# -->Bite: +15 to hit, 2d10+8 Piercing plus 3d6 Poison
# -->Claw: +15 to hit, 4d6+8 Slashing
# -->Tail: +15 to hit, 2d8+8 Bludgeoning
# -->Poison Breath: DC: 22 CON, 22d6 Poison
# Ancient Red Dragon - HP: 546 - CR: 24
# -->Bite: +17 to hit, 2d10+10 Bludgeoning plus 4d6 Fire
# -->Claw: +17 to hit, 2d6+10 Slashing
# -->Tail: +17 to hit, 2d8+10 Bludgeoning
# -->Fire Breath: DC: 24 DEX, 26d6 Fire
# Ancient Silver Dragon - HP: 487 - CR: 23
# -->Bite: +17 to hit, 2d10+10 Piercing
# -->Claw: +17 to hit, 2d6+10 Slashing
# -->Tail: +17 to hit, 2d8+10 Bludgeoning
# Ancient White Dragon - HP: 333 - CR: 20
# -->Bite: +14 to hit, 2d10+8 Piercing plus 2d8 Cold
# -->Claw: +14 to hit, 2d6+8 Slashing
# -->Tail: +14 to hit, 2d8+8 Bludgeoning
# -->Cold Breath: DC: 22 CON, 16d8 Cold
# Androsphinx - HP: 199 - CR: 17
# -->Claw: +12 to hit, 2d10+6 Slashing
# Animated Armor - HP: 33 - CR: 1
# -->Slam: +4 to hit, 1d6+2 Bludgeoning
# Ankheg - HP: 39 - CR: 2
# -->Bite: +5 to hit, 2d6+3 Slashing plus 1d6 Acid
# -->Acid Spray: DC: 13 DEX, 3d6 Acid
# Ape - HP: 19 - CR: 0.5
# -->Fist: +5 to hit, 1d6+3 Bludgeoning
# -->Rock: +5 to hit, 1d6+3 Bludgeoning
# Archmage - HP: 99 - CR: 12
# -->Dagger: +6 to hit, 1d4+2 Piercing
# Assassin - HP: 78 - CR: 8
# -->Shortsword: +6 to hit, 1d6+3 Piercing plus 7d6 Poison
# -->Light Crossbow: +6 to hit, 1d8+3 Piercing plus 7d6 Poison
# Awakened Shrub - HP: 10 - CR: 0
# -->Rake: +1 to hit, 1d4-1 Slashing
# Awakened Tree - HP: 59 - CR: 2
# -->Slam: +6 to hit, 3d6+4 Bludgeoning
# Axe Beak - HP: 19 - CR: 0.25
# -->Beak: +4 to hit, 1d8+2 Slashing
# Azer - HP: 39 - CR: 2
# -->Warhammer: +5 to hit, 1d8+3 Bludgeoning plus 1d6 Fire
# Baboon - HP: 3 - CR: 0
# -->Bite: +1 to hit, 1d4-1 Piercing
# Badger - HP: 3 - CR: 0
# -->Bite: +2 to hit, 1 Piercing
# Balor - HP: 262 - CR: 19
# -->Longsword: +14 to hit, 3d8+8 Slashing plus 3d8 Lightning
# -->Whip: +14 to hit, 2d6+8 Slashing plus 3d6 Fire
# Bandit - HP: 11 - CR: 0.125
# -->Scimitar: +3 to hit, 1d6+1 Slashing
# -->Light Crossbow: +3 to hit, 1d8+1 Piercing
# Bandit Captain - HP: 65 - CR: 2
# -->Scimitar: +5 to hit, 1d6+3 Slashing
# -->Dagger: +5 to hit, 1d4+3 Piercing
# Barbed Devil - HP: 110 - CR: 5
# -->Claw: +6 to hit, 1d6+3 Piercing
# -->Tail: +6 to hit, 2d6+3 Piercing
# -->Hurl Flame: +5 to hit, 3d6 Fire
# Basilisk - HP: 52 - CR: 3
# -->Bite: +5 to hit, 2d6+3 Piercing plus 2d6 Poison
# Bat - HP: 1 - CR: 0
# -->Bite: +0 to hit, 1 Piercing
# Bearded Devil - HP: 52 - CR: 3
# -->Beard: +5 to hit, 1d8+2 Piercing
# -->Glaive: +5 to hit, 1d10+3 Slashing
# Behir - HP: 168 - CR: 11
# -->Bite: +10 to hit, 3d10+6 Piercing
# -->Constrict: +10 to hit, 2d10+6 Bludgeoning plus 2d10+6 Slashing
# -->Lightning Breath: DC: 16 DEX, 12d10 Lightning
# -->Swallow: Conditional, 6d6 Acid
# Berserker - HP: 67 - CR: 2
# -->Greataxe: +5 to hit, 1d12+3 Slashing
# Black Bear - HP: 19 - CR: 0.5
# -->Bite: +3 to hit, 1d6+2 Piercing
# -->Claws: +3 to hit, 2d4+2 Slashing
# Black Dragon Wyrmling - HP: 33 - CR: 2
# -->Bite: +4 to hit, 1d10+2 Piercing plus 1d4 Acid
# -->Acid Breath: DC: 11 DEX, 5d8 Acid
# Black Pudding - HP: 85 - CR: 4
# -->Pseudopod: +5 to hit, 1d6+3 Bludgeoning plus 4d8 Acid
# Blink Dog - HP: 22 - CR: 0.25
# -->Bite: +3 to hit, 1d6+1 Piercing
# Blood Hawk - HP: 7 - CR: 0.125
# -->Beak: +4 to hit, 1d4+2 Piercing
# Blue Dragon Wyrmling - HP: 52 - CR: 3
# -->Bite: +5 to hit, 1d10+3 Piercing plus 1d6 Lightning
# -->Lightning Breath: DC: 12 DEX, 4d10 Bludgeoning
# Boar - HP: 11 - CR: 0.25
# -->Tusk: +3 to hit, 1d6+1 Slashing
# Bone Devil - HP: 142 - CR: 9
# -->Claw: +8 to hit, 1d8+4 Slashing
# -->Sting: +8 to hit, 2d8+4 Piercing plus 5d6 Poison
# Brass Dragon Wyrmling - HP: 16 - CR: 1
# -->Bite: +4 to hit, 1d10+2 Piercing
# Bronze Dragon Wyrmling - HP: 32 - CR: 2
# -->Bite: +5 to hit, 1d10+3 Piercing
# Brown Bear - HP: 34 - CR: 1
# -->Bite: +5 to hit, 1d8+4 Piercing
# -->Claws: +5 to hit, 2d6+4 Slashing
# Bugbear - HP: 27 - CR: 1
# -->Morningstar: +4 to hit, 2d8+2 Piercing
# -->Javelin: +4 to hit, 2d6+2 Piercing
# Bulette - HP: 94 - CR: 5
# -->Bite: +7 to hit, 4d12+4 Piercing
# Camel - HP: 15 - CR: 0.125
# -->Bite: +5 to hit, 1d4 Bludgeoning
# Cat - HP: 2 - CR: 0
# -->Claws: +0 to hit, 1 Slashing
# Centaur - HP: 45 - CR: 2
# -->Pike: +6 to hit, 1d10+4 Piercing
# -->Hooves: +6 to hit, 2d6+4 Bludgeoning
# -->Longbow: +4 to hit, 1d8+2 Piercing
# Chain Devil - HP: 85 - CR: 8
# -->Chain: +8 to hit, 2d6+4 Slashing
# Chimera - HP: 114 - CR: 6
# -->Bite: +7 to hit, 2d6+4 Piercing
# -->Horns: +7 to hit, 1d12+4 Bludgeoning
# -->Claws: +7 to hit, 2d6+4 Slashing
# -->Fire Breath: DC: 15 DEX, 7d8 Fire
# Chuul - HP: 93 - CR: 4
# -->Pincer: +6 to hit, 2d6+4 Bludgeoning
# Clay Golem - HP: 133 - CR: 9
# -->Slam: +8 to hit, 2d10+5 Bludgeoning
# Cloaker - HP: 78 - CR: 8
# -->Bite: +6 to hit, 2d6+3 Piercing
# -->Tail: +6 to hit, 1d8+3 Slashing
# Cloud Giant - HP: 200 - CR: 9
# -->Morningstar: +12 to hit, 3d8+8 Piercing
# -->Rock: +12 to hit, 4d10+8 Bludgeoning
# Cockatrice - HP: 27 - CR: 0.5
# -->Bite: +3 to hit, 1d4+1 Piercing
# Commoner - HP: 4 - CR: 0
# -->Club: +2 to hit, 1d4 Bludgeoning
# Constrictor Snake - HP: 13 - CR: 0.25
# -->Bite: +4 to hit, 1d6+2 Piercing
# -->Constrict: +4 to hit, 1d8+2 Bludgeoning
# Copper Dragon Wyrmling - HP: 22 - CR: 1
# -->Bite: +4 to hit, 1d10+2 Piercing
# Couatl - HP: 97 - CR: 4
# -->Bite: +8 to hit, 1d6+5 Piercing
# -->Constrict: +6 to hit, 2d6+3 Bludgeoning
# Crab - HP: 2 - CR: 0
# -->Claw: +0 to hit, 1 Bludgeoning
# Crocodile - HP: 19 - CR: 0.5
# -->Bite: +4 to hit, 1d10+2 Bludgeoning
# Cult Fanatic - HP: 22 - CR: 2
# -->Dagger: +4 to hit, 1d4+2 Piercing
# Cultist - HP: 9 - CR: 0.125
# -->Scimitar: +3 to hit, 1d6+1 Slashing
# Darkmantle - HP: 22 - CR: 0.5
# -->Crush: +5 to hit, 1d6+3 Bludgeoning
# Death Dog - HP: 39 - CR: 1
# -->Bite: +4 to hit, 1d6+2 Bludgeoning
# Deep Gnome (Svirfneblin) - HP: 16 - CR: 0.5
# -->War Pick: +4 to hit, 1d8+2 Piercing
# -->Poisoned Dart: +4 to hit, 1d4+2 Piercing
# Deer - HP: 4 - CR: 0
# -->Bite: +2 to hit, 1d4 Piercing
# Deva - HP: 136 - CR: 10
# -->Mace: +8 to hit, 1d6+4 Bludgeoning plus 4d8 Radiant
# Dire Wolf - HP: 37 - CR: 1
# -->Bite: +5 to hit, 2d6+3 Piercing
# Djinni - HP: 161 - CR: 11
# -->Scimitar: +9 to hit, 2d6+5 Slashing plus
# Doppelganger - HP: 52 - CR: 3
# -->Slam: +6 to hit, 1d6+4 Bludgeoning
# Draft Horse - HP: 19 - CR: 0.25
# -->Hooves: +6 to hit, 2d4+4 Bludgeoning
# Dragon Turtle - HP: 341 - CR: 17
# -->Bite: +13 to hit, 3d12+7 Piercing
# -->Claw: +13 to hit, 2d8+7 Piercing
# -->Tail: +13 to hit, 3d12+7 Bludgeoning
# -->Steam Breath: DC: 18 CON, 15d6 Fire
# Dretch - HP: 18 - CR: 0.25
# -->Bite: +2 to hit, 1d6 Piercing
# -->Claws: +2 to hit, 2d4 Slashing
# Drider - HP: 123 - CR: 6
# -->Bite: +6 to hit, 1d4 Piercing plus 2d8 Poison
# -->Longsword: +6 to hit,
# -->Longbow: +6 to hit, 1d8+3 Piercing plus 1d8 Poison
# Drow - HP: 13 - CR: 0.25
# -->Shortsword: +4 to hit, 1d6+2 Bludgeoning
# -->Hand Crossbow: +4 to hit, 1d6+2 Piercing
# Druid - HP: 27 - CR: 2
# -->Quarterstaff: +2 to hit,
# Dryad - HP: 22 - CR: 1
# -->Club: +2 to hit, 1d4 Bludgeoning
# Duergar - HP: 26 - CR: 1
# -->War Pick: +4 to hit, 1d8+2 Piercing
# -->Javelin: +4 to hit, 1d6+2 Bludgeoning
# Dust Mephit - HP: 17 - CR: 0.5
# -->Claws: +4 to hit, 1d4+2 Slashing
# Eagle - HP: 3 - CR: 0
# -->Talons: +4 to hit, 1d4+2 Bludgeoning
# Earth Elemental - HP: 126 - CR: 5
# -->Slam: +8 to hit, 2d8+5 Bludgeoning
# Efreeti - HP: 200 - CR: 11
# -->Scimitar: +10 to hit, 2d6+6 Slashing plus 2d6 Fire
# -->Hurl Flame: +7 to hit, 5d6 Fire
# Elephant - HP: 76 - CR: 4
# -->Gore: +8 to hit, 3d8+6 Piercing
# -->Stomp: +8 to hit, 3d10+6 Bludgeoning
# Elk - HP: 13 - CR: 0.25
# -->Ram: +5 to hit, 1d6+3 Bludgeoning
# -->Hooves: +5 to hit, 2d4+3 Bludgeoning
# Erinyes - HP: 153 - CR: 12
# -->Longsword: +8 to hit, 3d8 Poison plus
# -->Longbow: +7 to hit, 1d8+3 Piercing plus 3d8 Poison
# Ettercap - HP: 44 - CR: 2
# -->Bite: +4 to hit, 2d6+2 Piercing plus 1d8 Poison
# -->Claws: +4 to hit, 2d4+2 Bludgeoning
# Ettin - HP: 85 - CR: 4
# -->Battleaxe: +7 to hit, 2d8+5 Slashing
# -->Morningstar: +7 to hit, 2d8+5 Piercing
# Fire Elemental - HP: 102 - CR: 5
# -->Touch: +6 to hit, 2d6+3 Fire
# Fire Giant - HP: 162 - CR: 9
# -->Greatsword: +11 to hit, 6d6+7 Slashing
# -->Rock: +11 to hit, 4d10+7 Bludgeoning
# Flesh Golem - HP: 93 - CR: 5
# -->Slam: +7 to hit, 2d8+4 Bludgeoning
# Flying Snake - HP: 5 - CR: 0.125
# -->Bite: +6 to hit, 1 Bludgeoning plus 3d4 Poison
# Flying Sword - HP: 17 - CR: 0.25
# -->Longsword: +3 to hit, 1d8+1 Slashing
# Frog - HP: 1 - CR: 0
# Frost Giant - HP: 138 - CR: 8
# -->Greataxe: +9 to hit, 3d12+6 Slashing
# -->Rock: +9 to hit, 4d10+6 Bludgeoning
# Gargoyle - HP: 52 - CR: 2
# -->Bite: +4 to hit, 1d6+2 Piercing
# -->Claws: +4 to hit, 1d6+2 Slashing
# Gelatinous Cube - HP: 84 - CR: 2
# -->Pseudopod: +4 to hit, 3d6 Acid
# -->Engulf: DC: 12 DEX, 3d6 Acid
# Ghast - HP: 36 - CR: 2
# -->Bite: +3 to hit, 2d8+3 Piercing
# -->Claws: +5 to hit, 2d6+3 Slashing
# Ghost - HP: 45 - CR: 4
# -->Withering Touch: +5 to hit, 4d6+3 Necrotic
# Ghoul - HP: 22 - CR: 1
# -->Bite: +2 to hit, 2d6+2 Piercing
# -->Claws: +4 to hit, 2d4+2 Slashing
# Giant Ape - HP: 157 - CR: 7
# -->Fist: +9 to hit, 3d10+6 Bludgeoning
# -->Rock: +9 to hit, 7d6+6 Bludgeoning
# Giant Badger - HP: 13 - CR: 0.25
# -->Bite: +3 to hit, 1d6+1 Piercing
# -->Claws: +3 to hit, 2d4+1 Slashing
# Giant Bat - HP: 22 - CR: 0.25
# -->Bite: +4 to hit, 1d6+2 Piercing
# Giant Boar - HP: 42 - CR: 2
# -->Tusk: +5 to hit, 2d6+3 Slashing
# Giant Centipede - HP: 4 - CR: 0.25
# -->Bite: +4 to hit, 1d4+2 Piercing
# Giant Constrictor Snake - HP: 60 - CR: 2
# -->Bite: +6 to hit, 2d6+4 Piercing
# -->Constrict: +6 to hit, 2d8+4 Bludgeoning
# Giant Crab - HP: 13 - CR: 0.125
# -->Claw: +3 to hit, 1d6+1 Bludgeoning
# Giant Crocodile - HP: 85 - CR: 5
# -->Bite: +8 to hit, 3d10+5 Piercing
# -->Tail: +8 to hit, 2d8+5 Bludgeoning
# Giant Eagle - HP: 26 - CR: 1
# -->Beak: +5 to hit, 1d6+3 Piercing
# -->Talons: +5 to hit, 2d6+3 Slashing
# Giant Elk - HP: 42 - CR: 2
# -->Ram: +6 to hit, 2d6+4 Bludgeoning
# -->Hooves: +6 to hit, 4d8+4 Bludgeoning
# Giant Fire Beetle - HP: 4 - CR: 0
# -->Bite: +1 to hit, 1d6-1 Slashing
# Giant Frog - HP: 18 - CR: 0.25
# -->Bite: +3 to hit, 1d6+1 Piercing
# Giant Goat - HP: 19 - CR: 0.5
# -->Ram: +5 to hit, 2d4+3 Bludgeoning
# Giant Hyena - HP: 45 - CR: 1
# -->Bite: +5 to hit, 2d6+3 Piercing
# Giant Lizard - HP: 19 - CR: 0.25
# -->Bite: +4 to hit, 1d8+2 Piercing
# Giant Octopus - HP: 52 - CR: 1
# -->Tentacles: +5 to hit, 2d6+3 Bludgeoning
# Giant Owl - HP: 19 - CR: 0.25
# -->Talons: +3 to hit, 2d6+1 Slashing
# Giant Poisonous Snake - HP: 11 - CR: 0.25
# -->Bite: +6 to hit, 1d4+4 Piercing
# Giant Rat - HP: 7 - CR: 0.125
# -->Bite: +4 to hit, 1d4+2 Piercing
# Giant Rat (Diseased) - HP: 7 - CR: 0.125
# -->Bite: +4 to hit, 1d4+2 Piercing
# Giant Scorpion - HP: 52 - CR: 3
# -->Claw: +4 to hit, 1d8+2 Bludgeoning
# -->Sting: +4 to hit, 1d10+2 Piercing
# Giant Sea Horse - HP: 16 - CR: 0.5
# -->Ram: +3 to hit, 1d6+1 Bludgeoning
# Giant Shark - HP: 126 - CR: 5
# -->Bite: +9 to hit, 3d10+6 Piercing
# Giant Spider - HP: 26 - CR: 1
# -->Bite: +5 to hit, 1d8+3 Piercing
# Giant Toad - HP: 39 - CR: 1
# -->Bite: +4 to hit, 1d10+2 Piercing plus 1d10 Poison
# Giant Vulture - HP: 22 - CR: 1
# -->Beak: +4 to hit, 2d4+2 Piercing
# -->Talons: +4 to hit, 2d6+2 Slashing
# Giant Wasp - HP: 13 - CR: 0.5
# -->Sting: +4 to hit, 1d6+2 Piercing
# Giant Weasel - HP: 9 - CR: 0.125
# -->Bite: +5 to hit, 1d4+3 Piercing
# Giant Wolf Spider - HP: 11 - CR: 0.25
# -->Bite: +3 to hit, 1d6+1 Piercing
# Gibbering Mouther - HP: 67 - CR: 2
# -->Bites: +2 to hit, 5d6 Bludgeoning
# Glabrezu - HP: 157 - CR: 9
# -->Pincer: +9 to hit, 2d10+5 Bludgeoning
# -->Fist: +9 to hit, 2d4+2 Bludgeoning
# Gladiator - HP: 112 - CR: 5
# -->Spear: +7 to hit,
# -->Shield Bash: +7 to hit, 2d4+4 Bludgeoning
# Gnoll - HP: 22 - CR: 0.5
# -->Bite: +4 to hit, 1d4+2 Piercing
# -->Spear: +4 to hit,
# -->Longbow: +3 to hit, 1d8+1 Piercing
# Goat - HP: 4 - CR: 0
# -->Ram: +3 to hit, 1d4+1 Bludgeoning
# Goblin - HP: 7 - CR: 0.25
# -->Scimitar: +4 to hit, 1d6+2 Slashing
# -->Shortbow: +4 to hit, 1d6+2 Piercing
# Gold Dragon Wyrmling - HP: 60 - CR: 3
# -->Bite: +6 to hit, 1d10+4 Piercing
# Gorgon - HP: 114 - CR: 5
# -->Gore: +8 to hit, 2d12+5 Piercing
# -->Hooves: +8 to hit, 2d10+5 Bludgeoning
# Gray Ooze - HP: 22 - CR: 0.5
# -->Pseudopod: +3 to hit, 1d6+1 Bludgeoning plus 2d6 Acid
# Green Dragon Wyrmling - HP: 38 - CR: 2
# -->Bite: +4 to hit, 1d10+2 Piercing plus 1d6 Poison
# -->Poison Breath: DC: 11 CON, 6d6 Poison
# Green Hag - HP: 82 - CR: 3
# -->Claws: +6 to hit, 2d8+4 Slashing
# Grick - HP: 27 - CR: 2
# -->Tentacles: +4 to hit, 2d6+2 Slashing
# -->Beak: +4 to hit, 1d6+2 Piercing
# Griffon - HP: 59 - CR: 2
# -->Beak: +6 to hit, 1d8+4 Piercing
# -->Claws: +6 to hit, 2d6+4 Slashing
# Grimlock - HP: 11 - CR: 0.25
# -->Spiked Bone Club: +5 to hit, 1d4+3 Bludgeoning plus 1d4 Piercing
# Guard - HP: 11 - CR: 0.125
# -->Spear: +3 to hit,
# Guardian Naga - HP: 127 - CR: 10
# -->Bite: +8 to hit, 1d8+4 Piercing
# Gynosphinx - HP: 136 - CR: 11
# -->Claw: +9 to hit, 2d8+4 Slashing
# Half-Red Dragon Veteran - HP: 65 - CR: 5
# -->Longsword: +5 to hit,
# -->Shortsword: +5 to hit, 1d6+3 Piercing
# -->Heavy Crossbow: +3 to hit, 1d10+1 Piercing
# -->Fire Breath: DC: 15 DEX, 7d6 Fire
# Harpy - HP: 38 - CR: 1
# -->Claws: +3 to hit, 2d4+1 Slashing
# -->Club: +3 to hit, 1d4+1 Bludgeoning
# Hawk - HP: 1 - CR: 0
# -->Talons: +5 to hit, 1 Slashing
# Hell Hound - HP: 45 - CR: 3
# -->Bite: +5 to hit, 1d8+3 Piercing plus 2d6 Fire
# -->Fire Breath: DC: 12 DEX, 6d6 Fire
# Hezrou - HP: 136 - CR: 8
# -->Bite: +7 to hit, 2d10+4 Piercing
# -->Claws: +7 to hit, 2d6+4 Slashing
# Hill Giant - HP: 105 - CR: 5
# -->Greatclub: +8 to hit, 3d8+5 Bludgeoning
# -->Rock: +8 to hit, 3d10+5 Bludgeoning
# Hippogriff - HP: 19 - CR: 1
# -->Beak: +5 to hit, 1d10+3 Piercing
# -->Claws: +5 to hit, 2d6+3 Slashing
# Hobgoblin - HP: 11 - CR: 0.5
# -->Longsword: +3 to hit,
# -->Longbow: +3 to hit, 1d8+1 Piercing
# Homunculus - HP: 5 - CR: 0
# -->Bite: +4 to hit, 1 Piercing
# Horned Devil - HP: 178 - CR: 11
# -->Fork: +10 to hit, 2d8+6 Piercing
# -->Tail: +10 to hit, 1d8+6 Piercing
# -->Hurl Flame: +7 to hit, 4d6 Fire
# Hunter Shark - HP: 45 - CR: 2
# -->Bite: +6 to hit, 2d8+4 Bludgeoning
# Hydra - HP: 172 - CR: 8
# -->Bite: +8 to hit, 1d10+5 Piercing
# Hyena - HP: 5 - CR: 0
# -->Bite: +2 to hit, 1d6 Piercing
# Ice Devil - HP: 180 - CR: 14
# -->Bite: +10 to hit, 2d6+5 Piercing plus 3d6 Cold
# -->Claws: +10 to hit, 2d4+5 Slashing plus 3d6 Cold
# -->Tail: +10 to hit, 2d6+5 Bludgeoning plus 3d6 Cold
# Ice Mephit - HP: 21 - CR: 0.5
# -->Claws: +3 to hit, 1d4+1 Slashing plus 1d4 Cold
# -->Frost Breath: DC: 10 DEX, 2d4 Cold
# Imp - HP: 10 - CR: 1
# -->Sting (Bite in Beast Form): +5 to hit, 1d4+3 Piercing
# Invisible Stalker - HP: 104 - CR: 6
# -->Slam: +6 to hit, 2d6+3 Bludgeoning
# Iron Golem - HP: 210 - CR: 16
# -->Slam: +13 to hit, 3d8+7 Bludgeoning
# -->Sword: +13 to hit, 3d10+7 Slashing
# -->Poison Breath: DC: 19 CON, 10d8 Poison
# Jackal - HP: 3 - CR: 0
# -->Bite: +1 to hit, 1d4-1 Piercing
# Killer Whale - HP: 90 - CR: 3
# -->Bite: +6 to hit, 5d6+4 Piercing
# Knight - HP: 52 - CR: 3
# -->Greatsword: +5 to hit, 2d6+3 Slashing
# -->Heavy Crossbow: +2 to hit, 1d10 Piercing
# Kobold - HP: 5 - CR: 0.125
# -->Dagger: +4 to hit, 1d4+2 Piercing
# -->Sling: +4 to hit, 1d4+2 Bludgeoning
# Kraken - HP: 472 - CR: 23
# -->Bite: +7 to hit, 3d8+10 Piercing
# -->Tentacle: +7 to hit, 3d6+10 Bludgeoning
# -->Lightning Storm: DC: 23 DEX, 4d10 Lightning
# Lamia - HP: 97 - CR: 4
# -->Claws: +5 to hit, 2d10+3 Slashing
# -->Dagger: +5 to hit, 1d4+3 Piercing
# Lemure - HP: 13 - CR: 0
# -->Fist: +3 to hit, 1d4 Bludgeoning
# Lich - HP: 135 - CR: 21
# -->Paralyzing Touch: +12 to hit, 3d6 Cold
# Lion - HP: 26 - CR: 1
# -->Bite: +5 to hit, 1d8+3 Piercing
# -->Claw: +5 to hit, 1d6+3 Slashing
# Lizard - HP: 2 - CR: 0
# -->Bite: +0 to hit, 1 Piercing
# Lizardfolk - HP: 22 - CR: 0.5
# -->Bite: +4 to hit, 1d6+2 Piercing
# -->Heavy Club: +4 to hit, 1d6+2 Bludgeoning
# -->Javelin: +4 to hit, 1d6+2 Piercing
# -->Spiked Shield: +4 to hit, 1d6+2 Piercing
# Mage - HP: 40 - CR: 6
# -->Dagger: +5 to hit, 1d4+2 Piercing
# Magma Mephit - HP: 22 - CR: 0.5
# -->Claws: +3 to hit, 1d4+1 Slashing plus 1d4 Fire
# -->Fire Breath: DC: 11 DEX, 2d6 Fire
# Magmin - HP: 9 - CR: 0.5
# -->Touch: +4 to hit, 2d6 Fire
# Mammoth - HP: 126 - CR: 6
# -->Gore: +10 to hit, 4d8+7 Piercing
# -->Stomp: +10 to hit, 4d10+7 Bludgeoning
# Manticore - HP: 68 - CR: 3
# -->Bite: +5 to hit, 1d8+3 Piercing
# -->Claw: +5 to hit, 1d6+3 Slashing
# -->Tail Spike: +5 to hit, 1d8+3 Piercing
# Marilith - HP: 189 - CR: 16
# -->Longsword: +9 to hit, 2d8+4 Slashing
# -->Tail: +9 to hit, 2d10+4 Bludgeoning
# Mastiff - HP: 5 - CR: 0.125
# -->Bite: +3 to hit, 1d6+1 Piercing
# Medusa - HP: 127 - CR: 6
# -->Snake Hair: +5 to hit, 1d4+2 Piercing plus 4d6 Poison
# -->Shortsword: +5 to hit, 1d6+2 Piercing
# -->Longbow: +5 to hit, 1d8+2 Piercing plus 2d6 Poison
# Merfolk - HP: 11 - CR: 0.125
# -->Spear: +2 to hit,
# Merrow - HP: 45 - CR: 2
# -->Bite: +6 to hit, 1d8+4 Piercing
# -->Claws: +6 to hit, 2d4+4 Slashing
# -->Harpoon: +6 to hit, 2d6+4 Piercing
# Mimic - HP: 58 - CR: 2
# -->Pseudopod: +5 to hit, 1d8+3 Bludgeoning
# -->Bite: +5 to hit, 1d8+3 Piercing plus 1d8 Acid
# Minotaur - HP: 76 - CR: 3
# -->Greataxe: +6 to hit, 2d12+4 Slashing
# -->Gore: +6 to hit, 2d8+4 Piercing
# Minotaur Skeleton - HP: 67 - CR: 2
# -->Greataxe: +6 to hit, 2d12+4 Slashing
# -->Gore: +6 to hit, 2d8+4 Piercing
# Mule - HP: 11 - CR: 0.125
# -->Hooves: +2 to hit, 1d4+2 Bludgeoning
# Mummy - HP: 58 - CR: 3
# -->Rotting Fist: +5 to hit, 2d6+3 Bludgeoning plus 3d6 Necrotic
# Mummy Lord - HP: 97 - CR: 15
# -->Rotting Fist: +9 to hit, 3d6+4 Bludgeoning plus 6d6 Necrotic
# Nalfeshnee - HP: 184 - CR: 13
# -->Bite: +10 to hit, 5d10+5 Piercing
# -->Claw: +10 to hit, 3d6+5 Slashing
# Night Hag - HP: 112 - CR: 5
# -->Claws (Hag Form Only): +7 to hit, 2d8+4 Slashing
# Nightmare - HP: 68 - CR: 3
# -->Hooves: +6 to hit, 2d8+4 Bludgeoning plus 2d6 Fire
# Noble - HP: 9 - CR: 0.125
# -->Rapier: +3 to hit, 1d8+1 Bludgeoning
# Ochre Jelly - HP: 45 - CR: 2
# -->Pseudopod: +4 to hit, 2d6+2 Bludgeoning plus 1d6 Acid
# Octopus - HP: 3 - CR: 0
# -->Tentacles: +4 to hit, 1 Bludgeoning
# Ogre - HP: 59 - CR: 2
# -->Greatclub: +6 to hit, 2d8+4 Bludgeoning
# -->Javelin: +6 to hit, 2d6+4 Piercing
# Ogre Zombie - HP: 85 - CR: 2
# -->Morningstar: +6 to hit, 2d8+4 Bludgeoning
# Oni - HP: 110 - CR: 7
# -->Claw (Oni Form Only): +7 to hit, 1d8+4 Slashing
# -->Glaive: +7 to hit, 2d10+4 Slashing
# Orc - HP: 15 - CR: 0.5
# -->Greataxe: +5 to hit, 1d12+3 Slashing
# -->Javelin: +5 to hit, 1d6+3 Piercing
# Otyugh - HP: 114 - CR: 5
# -->Bite: +6 to hit, 2d8+3 Piercing
# -->Tentacle: +6 to hit, 1d8+3 Bludgeoning plus 1d8 Piercing
# Owl - HP: 1 - CR: 0
# -->Talons: +3 to hit, 1 Slashing
# Owlbear - HP: 59 - CR: 3
# -->Beak: +7 to hit, 1d10+5 Piercing
# -->Claws: +7 to hit, 2d8+5 Slashing
# Panther - HP: 13 - CR: 0.25
# -->Bite: +4 to hit, 1d6+2 Piercing
# -->Claw: +4 to hit, 1d4+2 Slashing
# Pegasus - HP: 59 - CR: 2
# -->Hooves: +6 to hit, 2d6+4 Bludgeoning
# Phase Spider - HP: 32 - CR: 3
# -->Bite: +4 to hit, 1d10+2 Piercing
# Pit Fiend - HP: 300 - CR: 20
# -->Bite: +14 to hit, 4d6+8 Piercing
# -->Claw: +14 to hit, 2d8+8 Slashing
# -->Mace: +14 to hit, 2d6+8 Bludgeoning
# -->Tail: +14 to hit, 3d10+8 Bludgeoning
# Planetar - HP: 200 - CR: 16
# -->Greatsword: +12 to hit, 4d6+7 Slashing plus 5d8 Radiant
# Plesiosaurus - HP: 68 - CR: 2
# -->Bite: +6 to hit, 3d6+4 Bludgeoning
# Poisonous Snake - HP: 2 - CR: 0.125
# -->Bite: +5 to hit, 1 Piercing
# Polar Bear - HP: 42 - CR: 2
# -->Bite: +7 to hit, 1d8+5 Piercing
# -->Claws: +7 to hit, 2d6+5 Slashing
# Pony - HP: 11 - CR: 0.125
# -->Hooves: +4 to hit, 2d4+2 Bludgeoning
# Priest - HP: 27 - CR: 2
# -->Mace: +2 to hit, 1d6 Bludgeoning
# Pseudodragon - HP: 7 - CR: 0.25
# -->Bite: +4 to hit, 1d4+2 Piercing
# -->Sting: +4 to hit, 1d4+2 Piercing
# Purple Worm - HP: 247 - CR: 15
# -->Bite: +9 to hit, 3d8+9 Piercing
# -->Tail Stinger: +9 to hit, 3d6+9 Piercing
# Quasit - HP: 7 - CR: 1
# -->Claw (Bite in Beast Form): +4 to hit, 1d4+3 Piercing
# Quipper - HP: 1 - CR: 0
# -->Bite: +5 to hit, 1 Piercing
# Rakshasa - HP: 110 - CR: 13
# -->Claw: +7 to hit, 2d6+2 Slashing
# Rat - HP: 1 - CR: 0
# -->Bite: +0 to hit, 1 Piercing
# Raven - HP: 1 - CR: 0
# -->Beak: +4 to hit, 1 Piercing
# Red Dragon Wyrmling - HP: 75 - CR: 4
# -->Bite: +6 to hit, 1d10+4 Piercing plus 1d6 Fire
# -->Fire Breath: DC: 13 DEX, 7d6 Fire
# Reef Shark - HP: 22 - CR: 0.5
# -->Bite: +4 to hit, 1d8+2 Piercing
# Remorhaz - HP: 195 - CR: 11
# -->Bite: +11 to hit, 6d10+7 Piercing plus 3d6 Fire
# Rhinoceros - HP: 45 - CR: 2
# -->Gore: +7 to hit, 2d8+5 Bludgeoning
# Riding Horse - HP: 13 - CR: 0.25
# -->Hooves: +5 to hit, 2d4+3 Bludgeoning
# Roc - HP: 248 - CR: 11
# -->Beak: +13 to hit, 4d8+9 Piercing
# -->Talons: +13 to hit, 4d6+9 Slashing
# Roper - HP: 93 - CR: 5
# -->Bite: +7 to hit, 4d8+4 Piercing
# Rug of Smothering - HP: 33 - CR: 2
# Rust Monster - HP: 27 - CR: 0.5
# -->Bite: +3 to hit, 1d8+1 Piercing
# Saber-Toothed Tiger - HP: 52 - CR: 2
# -->Bite: +6 to hit, 1d10+5 Piercing
# -->Claw: +6 to hit, 2d6+5 Slashing
# Sahuagin - HP: 22 - CR: 0.5
# -->Bite: +3 to hit, 1d4+1 Piercing
# -->Claws: +3 to hit, 1d4+1 Slashing
# -->Spear: +3 to hit,
# Salamander - HP: 90 - CR: 5
# -->Spear: +7 to hit, 1d6 Fire plus
# -->Tail: +7 to hit, 2d6+4 Bludgeoning plus 2d6 Fire
# Satyr - HP: 31 - CR: 0.5
# -->Ram: +3 to hit, 2d4+1 Bludgeoning
# -->Shortsword: +5 to hit, 1d6+3 Piercing
# -->Shortbow: +5 to hit, 1d6+3 Piercing
# Scorpion - HP: 1 - CR: 0
# -->Sting: +2 to hit, 1 Bludgeoning
# Scout - HP: 16 - CR: 0.5
# -->Shortsword: +4 to hit, 1d6+2 Piercing
# -->Longbow: +4 to hit, 1d8+2 Piercing
# Sea Hag - HP: 52 - CR: 2
# -->Claws: +5 to hit, 2d6+3 Slashing
# Sea Horse - HP: 1 - CR: 0
# Shadow - HP: 16 - CR: 0.5
# -->Strength Drain: +4 to hit, 2d6+2 Necrotic
# Shambling Mound - HP: 136 - CR: 5
# -->Slam: +7 to hit, 2d8+4 Bludgeoning
# Shield Guardian - HP: 142 - CR: 7
# -->Fist: +7 to hit, 2d6+4 Bludgeoning
# Shrieker - HP: 13 - CR: 0
# Silver Dragon Wyrmling - HP: 45 - CR: 2
# -->Bite: +6 to hit, 1d10+4 Piercing
# Skeleton - HP: 13 - CR: 0.25
# -->Shortsword: +4 to hit, 1d6+2 Piercing
# -->Shortbow: +4 to hit, 1d6+2 Piercing
# Solar - HP: 243 - CR: 21
# -->Greatsword: +15 to hit, 4d6+8 Radiant plus 6d8 Radiant
# -->Slaying Longbow: +13 to hit, 2d8+6 Piercing plus 6d8 Radiant
# Specter - HP: 22 - CR: 1
# -->Life Drain: +4 to hit, 3d6 Necrotic
# Spider - HP: 1 - CR: 0
# -->Bite: +4 to hit, 1 Piercing
# Spirit Naga - HP: 75 - CR: 8
# -->Bite: +7 to hit, 1d6+4 Piercing
# Sprite - HP: 2 - CR: 0.25
# -->Longsword: +2 to hit, 1 Slashing
# -->Shortbow: +6 to hit, 1 Piercing
# Spy - HP: 27 - CR: 1
# -->Shortsword: +4 to hit, 1d6+2 Piercing
# -->Hand Crossbow: +4 to hit, 1d6+2 Piercing
# Steam Mephit - HP: 21 - CR: 0.25
# -->Claws: +2 to hit, 1d4 Slashing plus 1d4 Fire
# -->Steam Breath: DC: 10 DEX, 1d8 Fire
# Stirge - HP: 2 - CR: 0.125
# -->Blood Drain: +5 to hit, 1d4+3 Piercing
# Stone Giant - HP: 126 - CR: 7
# -->Greatclub: +9 to hit, 3d8+6 Bludgeoning
# -->Rock: +9 to hit, 4d10+6 Bludgeoning
# Stone Golem - HP: 178 - CR: 10
# -->Slam: +10 to hit, 3d8+6 Bludgeoning
# Storm Giant - HP: 230 - CR: 13
# -->Greatsword: +14 to hit, 6d6+9 Slashing
# -->Rock: +14 to hit, 4d12+9 Bludgeoning
# -->Lightning Strike: DC: 17 DEX, 12d8 Lightning
# Succubus/Incubus - HP: 66 - CR: 4
# -->Claw (Fiend Form Only): +5 to hit, 1d6+3 Slashing
# -->Draining Kiss: +0 to hit, 5d10+5 Psychic
# Swarm of Bats - HP: 22 - CR: 0.25
# -->Bites: +4 to hit, 2d4 Piercing
# Swarm of Beetles - HP: 22 - CR: 0.5
# -->Bites: +3 to hit, 4d4 Piercing
# Swarm of Centipedes - HP: 22 - CR: 0.5
# -->Bites: +3 to hit, 4d4 Piercing
# Swarm of Insects - HP: 22 - CR: 0.5
# -->Bites: +3 to hit, 4d4 Piercing
# Swarm of Poisonous Snakes - HP: 36 - CR: 2
# -->Bites: +6 to hit, 2d6 Piercing
# Swarm of Quippers - HP: 28 - CR: 1
# -->Bites: +5 to hit, 4d6 Piercing
# Swarm of Rats - HP: 24 - CR: 0.25
# -->Bites: +2 to hit, 2d6 Piercing
# Swarm of Ravens - HP: 24 - CR: 0.25
# -->Beaks: +4 to hit, 2d6 Piercing
# Swarm of Spiders - HP: 22 - CR: 0.5
# -->Bites: +3 to hit, 4d4 Piercing
# Swarm of Wasps - HP: 22 - CR: 0.5
# -->Bites: +3 to hit, 4d4 Piercing
# Tarrasque - HP: 676 - CR: 30
# -->Bite: +19 to hit, 4d12+10 Piercing
# -->Claw: +19 to hit, 4d8+10 Slashing
# -->Horns: +19 to hit, 4d10+10 Piercing
# -->Tail: +19 to hit, 4d6+10 Bludgeoning
# Thug - HP: 32 - CR: 0.5
# -->Mace: +4 to hit, 1d6+2 Bludgeoning
# -->Heavy Crossbow: +2 to hit, 1d10 Piercing
# Tiger - HP: 37 - CR: 1
# -->Bite: +5 to hit, 1d10+3 Piercing
# -->Claw: +5 to hit, 1d8+3 Slashing
# Treant - HP: 138 - CR: 9
# -->Slam: +10 to hit, 3d6+6 Bludgeoning
# -->Rock: +10 to hit, 4d10+6 Bludgeoning
# Tribal Warrior - HP: 11 - CR: 0.125
# -->Spear: +3 to hit,
# Triceratops - HP: 95 - CR: 5
# -->Gore: +9 to hit, 4d8+6 Piercing
# -->Stomp: +9 to hit, 3d10+6 Bludgeoning
# Troll - HP: 84 - CR: 5
# -->Bite: +7 to hit, 1d6+4 Piercing
# -->Claw: +7 to hit, 2d6+4 Slashing
# Tyrannosaurus Rex - HP: 136 - CR: 8
# -->Bite: +10 to hit, 4d12+7 Piercing
# -->Tail: +10 to hit, 3d8+7 Bludgeoning
# Unicorn - HP: 67 - CR: 5
# -->Hooves: +7 to hit, 2d6+4 Bludgeoning
# -->Horn: +7 to hit, 1d8+4 Piercing
# Vampire, Bat Form - HP: 144 - CR: 13
# -->Bite: +9 to hit, 1d6+4 Piercing plus 3d6 Necrotic
# Vampire, Mist Form - HP: 144 - CR: 13
# Vampire Spawn - HP: 82 - CR: 5
# -->Bite: +6 to hit, 1d6+3 Piercing plus 2d6 Necrotic
# -->Claws: +6 to hit, 2d4+3 Slashing
# Vampire, Vampire Form - HP: 144 - CR: 13
# -->Unarmed Strike: +9 to hit, 1d8+4 Bludgeoning
# -->Bite: +9 to hit, 1d6+4 Piercing plus 3d6 Necrotic
# Veteran - HP: 58 - CR: 3
# -->Longsword: +5 to hit,
# -->Shortsword: +5 to hit, 1d6+3 Piercing
# -->Heavy Crossbow: +3 to hit, 1d10+1 Piercing
# Violet Fungus - HP: 18 - CR: 0.25
# -->Rotting Touch: +2 to hit, 1d8 Necrotic
# Vrock - HP: 104 - CR: 6
# -->Beak: +6 to hit, 2d6+3 Piercing
# -->Talons: +6 to hit, 2d10+3 Slashing
# Vulture - HP: 5 - CR: 0
# -->Beak: +2 to hit, 1d4 Piercing
# Warhorse - HP: 19 - CR: 0.5
# -->Hooves: +6 to hit, 2d6+4 Bludgeoning
# Warhorse Skeleton - HP: 22 - CR: 0.5
# -->Hooves: +6 to hit, 2d6+4 Bludgeoning
# Water Elemental - HP: 114 - CR: 5
# -->Slam: +7 to hit, 2d8+4 Bludgeoning
# -->Whelm: DC: 15 STR, 2d8+4 Bludgeoning
# Weasel - HP: 1 - CR: 0
# -->Bite: +5 to hit, 1 Piercing
# Werebear, Bear Form - HP: 135 - CR: 5
# -->Bite: +7 to hit, 2d10+4 Piercing
# -->Claw: +7 to hit, 2d8+4 Slashing
# Werebear, Human Form - HP: 135 - CR: 5
# -->Greataxe: +7 to hit, 1d12+4 Slashing
# Werebear, Hybrid Form - HP: 135 - CR: 5
# -->Bite: +7 to hit, 2d10+4 Piercing
# -->Claw: +7 to hit, 2d8+4 Slashing
# -->Greataxe: +7 to hit, 1d12+4 Slashing
# Wereboar, Boar Form - HP: 78 - CR: 4
# -->Tusks: +5 to hit, 2d6+3 Slashing
# Wereboar, Human Form - HP: 78 - CR: 4
# -->Maul: +5 to hit, 2d6+3 Bludgeoning
# Wereboar, Hybrid Form - HP: 78 - CR: 4
# -->Maul: +5 to hit, 2d6+3 Bludgeoning
# -->Tusks: +5 to hit, 2d6+3 Slashing
# Wererat, Human Form - HP: 33 - CR: 2
# -->Shortsword: +4 to hit, 1d6+2 Piercing
# -->Hand Crossbow: +4 to hit, 1d6+2 Piercing
# Wererat, Hybrid Form - HP: 33 - CR: 2
# -->Bite: +4 to hit, 1d4+2 Piercing
# -->Shortsword: +4 to hit, 1d6+2 Piercing
# -->Hand Crossbow: +4 to hit, 1d6+2 Piercing
# Wererat, Rat Form - HP: 33 - CR: 2
# -->Bite: +4 to hit, 1d4+2 Piercing
# Weretiger, Human Form - HP: 120 - CR: 4
# -->Scimitar: +5 to hit, 1d6+3 Slashing
# -->Longbow: +4 to hit, 1d8+2 Piercing
# Weretiger, Hybrid Form - HP: 120 - CR: 4
# -->Bite: +5 to hit, 1d10+3 Piercing
# -->Claw: +5 to hit, 1d8+3 Slashing
# -->Scimitar: +5 to hit, 1d6+3 Slashing
# -->Longbow: +4 to hit, 1d8+2 Piercing
# Weretiger, Tiger Form - HP: 120 - CR: 4
# -->Bite: +5 to hit, 1d10+3 Piercing
# -->Claw: +5 to hit, 1d8+3 Slashing
# Werewolf, Human Form - HP: 58 - CR: 3
# -->Spear: +4 to hit,
# Werewolf, Hybrid Form - HP: 58 - CR: 3
# -->Bite: +4 to hit, 1d8+2 Piercing
# -->Claws: +4 to hit, 2d4+2 Slashing
# Werewolf, Wolf Form - HP: 58 - CR: 3
# -->Bite: +4 to hit, 1d8+2 Piercing
# White Dragon Wyrmling - HP: 32 - CR: 2
# -->Bite: +4 to hit, 1d10+2 Piercing plus 1d4 Cold
# -->Cold Breath: DC: 12 CON, 5d8 Cold
# Wight - HP: 45 - CR: 3
# -->Life Drain: +4 to hit, 1d6+2 Necrotic
# -->Longsword: +4 to hit,
# -->Longbow: +4 to hit, 1d8+2 Piercing
# Will-o'-Wisp - HP: 22 - CR: 2
# -->Shock: +4 to hit, 2d8 Lightning
# Winter Wolf - HP: 75 - CR: 3
# -->Bite: +6 to hit, 2d6+4 Piercing
# -->Cold Breath: DC: 12 DEX, 4d8 Cold
# Wolf - HP: 11 - CR: 0.25
# -->Bite: +4 to hit, 2d4+2 Piercing
# Worg - HP: 26 - CR: 0.5
# -->Bite: +5 to hit, 2d6+3 Piercing
# Wraith - HP: 67 - CR: 5
# -->Life Drain: +6 to hit, 4d8+3 Necrotic
# Wyvern - HP: 110 - CR: 6
# -->Bite: +7 to hit, 2d6+4 Piercing
# -->Claws: +7 to hit, 2d8+4 Slashing
# -->Stinger: +7 to hit, 2d6+4 Piercing
# Xorn - HP: 73 - CR: 5
# -->Bite: +6 to hit, 3d6+3 Piercing
# -->Claw: +6 to hit, 1d6+3 Slashing
# Young Black Dragon - HP: 127 - CR: 7
# -->Bite: +7 to hit, 2d10+4 Piercing plus 1d8 Acid
# -->Claw: +7 to hit, 2d6+4 Slashing
# -->Acid Breath: DC: 14 DEX, 11d8 Acid
# Young Blue Dragon - HP: 152 - CR: 9
# -->Bite: +9 to hit, 2d10+5 Piercing plus 1d10 Lightning
# -->Claw: +9 to hit, 2d6+5 Slashing
# -->Lightning Breath: DC: 16 DEX, 10d10 Lightning
# Young Brass Dragon - HP: 110 - CR: 6
# -->Bite: +7 to hit, 2d10+4 Piercing
# -->Claw: +7 to hit, 2d6+4 Slashing
# Young Bronze Dragon - HP: 142 - CR: 8
# -->Bite: +8 to hit, 2d10+5 Piercing
# -->Claw: +8 to hit, 2d6+5 Slashing
# Young Copper Dragon - HP: 119 - CR: 7
# -->Bite: +7 to hit, 2d10+4 Piercing
# -->Claw: +7 to hit, 2d6+4 Slashing
# Young Gold Dragon - HP: 178 - CR: 10
# -->Bite: +10 to hit, 2d10+6 Piercing
# -->Claw: +10 to hit, 2d6+6 Slashing
# Young Green Dragon - HP: 136 - CR: 8
# -->Bite: +7 to hit, 2d10+4 Piercing plus 2d6 Poison
# -->Claw: +7 to hit, 2d6+4 Slashing
# -->Poison Breath: DC: 14 CON, 12d6 Poison
# Young Red Dragon - HP: 178 - CR: 10
# -->Bite: +10 to hit, 2d10+6 Piercing plus 1d6 Fire
# -->Claw: +10 to hit, 2d6+6 Slashing
# -->Fire Breath: DC: 17 DEX, 16d6 Fire
# Young Silver Dragon - HP: 168 - CR: 9
# -->Bite: +10 to hit, 2d10+6 Piercing
# -->Claw: +10 to hit, 2d6+6 Slashing
# Young White Dragon - HP: 133 - CR: 6
# -->Bite: +7 to hit, 2d10+4 Piercing plus 1d8 Cold
# -->Claw: +7 to hit, 2d6+4 Slashing
# -->Cold Breath: DC: 15 CON, 10d8 Cold
# Zombie - HP: 22 - CR: 0.25
# -->Slam: +3 to hit, 1d6+1 Bludgeoning

# %%
monster_url = monsters_data["results"][10]["url"]
monster = fetch_data(base_url + monster_url, headers)
monster
# Out:
# {'index': 'adult-silver-dragon',
#  'name': 'Adult Silver Dragon',
#  'size': 'Huge',
#  'type': 'dragon',
#  'alignment': 'lawful good',
#  'armor_class': [{'type': 'natural', 'value': 19}],
#  'hit_points': 243,
#  'hit_dice': '18d12',
#  'hit_points_roll': '18d12+126',
#  'speed': {'walk': '40 ft.', 'fly': '80 ft.'},
#  'strength': 27,
#  'dexterity': 10,
#  'constitution': 25,
#  'intelligence': 16,
#  'wisdom': 13,
#  'charisma': 21,
#  'proficiencies': [{'value': 5,
#    'proficiency': {'index': 'saving-throw-dex',
#     'name': 'Saving Throw: DEX',
#     'url': '/api/2014/proficiencies/saving-throw-dex'}},
#   {'value': 12,
#    'proficiency': {'index': 'saving-throw-con',
#     'name': 'Saving Throw: CON',
#     'url': '/api/2014/proficiencies/saving-throw-con'}},
#   {'value': 6,
#    'proficiency': {'index': 'saving-throw-wis',
#     'name': 'Saving Throw: WIS',
#     'url': '/api/2014/proficiencies/saving-throw-wis'}},
#   {'value': 10,
#    'proficiency': {'index': 'saving-throw-cha',
#     'name': 'Saving Throw: CHA',
#     'url': '/api/2014/proficiencies/saving-throw-cha'}},
#   {'value': 8,
#    'proficiency': {'index': 'skill-arcana',
#     'name': 'Skill: Arcana',
#     'url': '/api/2014/proficiencies/skill-arcana'}},
#   {'value': 8,
#    'proficiency': {'index': 'skill-history',
#     'name': 'Skill: History',
#     'url': '/api/2014/proficiencies/skill-history'}},
#   {'value': 11,
#    'proficiency': {'index': 'skill-perception',
#     'name': 'Skill: Perception',
#     'url': '/api/2014/proficiencies/skill-perception'}},
#   {'value': 5,
#    'proficiency': {'index': 'skill-stealth',
#     'name': 'Skill: Stealth',
#     'url': '/api/2014/proficiencies/skill-stealth'}}],
#  'damage_vulnerabilities': [],
#  'damage_resistances': [],
#  'damage_immunities': ['cold'],
#  'condition_immunities': [],
#  'senses': {'blindsight': '60 ft.',
#   'darkvision': '120 ft.',
#   'passive_perception': 21},
#  'languages': 'Common, Draconic',
#  'challenge_rating': 16,
#  'proficiency_bonus': 5,
#  'xp': 15000,
#  'special_abilities': [{'name': 'Legendary Resistance',
#    'desc': 'If the dragon fails a saving throw, it can choose to succeed instead.',
#    'usage': {'type': 'per day', 'times': 3, 'rest_types': []}}],
#  'actions': [{'name': 'Multiattack',
#    'multiattack_type': 'actions',
#    'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.',
#    'actions': [{'action_name': 'Frightful Presence',
#      'count': 1,
#      'type': 'ability'},
#     {'action_name': 'Bite', 'count': 1, 'type': 'melee'},
#     {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]},
#   {'name': 'Bite',
#    'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.',
#    'attack_bonus': 13,
#    'damage': [{'damage_type': {'index': 'piercing',
#       'name': 'Piercing',
#       'url': '/api/2014/damage-types/piercing'},
#      'damage_dice': '2d10+8'}],
#    'actions': []},
#   {'name': 'Claw',
#    'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.',
#    'attack_bonus': 13,
#    'damage': [{'damage_type': {'index': 'slashing',
#       'name': 'Slashing',
#       'url': '/api/2014/damage-types/slashing'},
#      'damage_dice': '2d6+8'}],
#    'actions': []},
#   {'name': 'Tail',
#    'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.',
#    'attack_bonus': 13,
#    'damage': [{'damage_type': {'index': 'bludgeoning',
#       'name': 'Bludgeoning',
#       'url': '/api/2014/damage-types/bludgeoning'},
#      'damage_dice': '2d8+8'}],
#    'actions': []},
#   {'name': 'Frightful Presence',
#    'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.",
#    'dc': {'dc_type': {'index': 'wis',
#      'name': 'WIS',
#      'url': '/api/2014/ability-scores/wis'},
#     'dc_value': 18,
#     'success_type': 'none'},
#    'actions': []},
#   {'name': 'Breath Weapons',
#    'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.',
#    'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5},
#    'options': {'choose': 1,
#     'type': 'attack',
#     'from': {'option_set_type': 'options_array',
#      'options': [{'option_type': 'breath',
#        'name': 'Cold Breath',
#        'dc': {'dc_type': {'index': 'con',
#          'name': 'CON',
#          'url': '/api/2014/ability-scores/con'},
#         'dc_value': 20,
#         'success_type': 'half'},
#        'damage': [{'damage_type': {'index': 'cold',
#           'name': 'Cold',
#           'url': '/api/2014/damage-types/cold'},
#          'damage_dice': '13d8'}]},
#       {'option_type': 'breath',
#        'name': 'Paralyzing Breath',
#        'dc': {'dc_type': {'index': 'con',
#          'name': 'CON',
#          'url': '/api/2014/ability-scores/con'},
#         'dc_value': 20,
#         'success_type': 'none'}}]}},
#    'actions': []}],
#  'legendary_actions': [{'name': 'Detect',
#    'desc': 'The dragon makes a Wisdom (Perception) check.'},
#   {'name': 'Tail Attack', 'desc': 'The dragon makes a tail attack.'},
#   {'name': 'Wing Attack (Costs 2 Actions)',
#    'desc': 'The dragon beats its wings. Each creature within 10 ft. of the dragon must succeed on a DC 22 Dexterity saving throw or take 15 (2d6 + 8) bludgeoning damage and be knocked prone. The dragon can then fly up to half its flying speed.',
#    'dc': {'dc_type': {'index': 'dex',
#      'name': 'DEX',
#      'url': '/api/2014/ability-scores/dex'},
#     'dc_value': 22,
#     'success_type': 'none'},
#    'damage': [{'damage_type': {'index': 'bludgeoning',
#       'name': 'Bludgeoning',
#       'url': '/api/2014/damage-types/bludgeoning'},
#      'damage_dice': '2d6+8'}]}],
#  'image': '/api/2014/images/monsters/adult-silver-dragon.png',
#  'url': '/api/2014/monsters/adult-silver-dragon',
#  'updated_at': '2025-03-19T04:12:44.620Z'}

# %%
import random
import math

class Monster:
    def __init__(self, monster_data):
        self._type = "monster"
        self._stats = {"STR": monster_data["strength"], "DEX": monster_data["dexterity"], "CON": monster_data["constitution"], "INT": monster_data["intelligence"], "WIS": monster_data["wisdom"], "CHA": monster_data["charisma"]}
        self._modifiers = {}
        for stat in self._stats.keys():
          score = self._stats[stat]
          modifier = math.floor((score - 10) / 2)
          self._modifiers[stat] = modifier

        self._challenge_rating = monster_data["challenge_rating"]
        self._prof_bonus = 2

        self._hp_max = monster_data["hit_points"]
        self._hp = self._hp_max
        self._ac = monster_data["armor_class"]
        self._initiative = self._modifiers["DEX"]
        self._status = "conscious"

        self._death_saves = {"successes": 0, "failures": 0}

        self._proficiency_bonus = 2
        self._proficiencies = {
            "saving_throws": [],
            "skills": []
        }
        for proficiency in monster_data["proficiencies"]:
          profType = proficiency["proficiency"]["name"].split(": ")
          if profType[0] == "Saving Throw":
            self._proficiencies["saving_throws"].append({
                "stat": profType[1],
                "value": proficiency["value"]
              })
          elif profType[0] == "Skill":
            self._proficiencies["skills"].append({
                "skill": profType[1],
                "value": proficiency["value"]
              })

        self._dmg_vulnerabilities = monster_data['damage_vulnerabilities']
        self._dmg_resistances = monster_data['damage_resistances']
        self._dmg_immunities = monster_data['damage_immunities']
        self._dmg_immunities = monster_data['condition_immunities']

        self._actions = []
        multiattack_actions = []
        for original_action in monster_data["actions"]:
          print("OG Action:\t" + str(original_action))
          if original_action["name"] not in multiattack_actions:
            if original_action["name"] == "Multiattack":
              print("MULTIATTACK")

              attacks = []
              for multi_act in original_action["actions"]:
                print("Multi act: " + str(multi_act))

                for act in monster_data["actions"]:
                  print("\t" + str(act))
                  if act["name"] == multi_act["action_name"] and act["name"] != "Multiattack" and multi_act["type"] != "ability":
                    print("FOUND:\t" + str(act))

                    for count in range(multi_act["count"]):
                      attack = {
                          "attack_bonus": act["attack_bonus"],
                          "sources": []
                      }
                      for source in act['damage']:
                        if 'choose' not in source:
                          dmg = source["damage_dice"].split("+")
                          attack["sources"].append({
                              "dmg_type": source["damage_type"]["name"],
                              "dmg_dice": dmg[0].split("d")[1],
                              "dmg_bonus": dmg[1]
                          })
                      multiattack_actions.append(act["name"])
                      attacks.append(attack)
              action = {
                "name": original_action["name"],
                "type": "attack",
                "attacks": attacks
              }
            elif "usage" in original_action:
              action = {
                "name": original_action["name"],
                "type": "attack",
                "attack_type": "usage"
              }
            elif "dc" in original_action:
              action = {
                "name": original_action["name"],
                "type": "dc",
                "dc_stat": original_action["dc"]["dc_type"]["name"],
                "dc_value": original_action["dc"]["dc_value"]
              }

            else:
              action = {
                  "name": original_action["name"],
                  "type": "attack",
                  "attacks": [{
                    "attack_bonus": original_action["attack_bonus"],
                    "sources": []
                  }]
                }
              for source in original_action['damage']:
                if 'choose' not in source:
                  dmg = source["damage_dice"].split("+")
                  action["attacks"][0]["sources"].append({
                      "dmg_type": source["damage_type"]["name"],
                      "dmg_dice": dmg[0].split("d")[1],
                      "dmg_bonus": dmg[1]
                  })

            self._actions.append(action)

    def use_action(self, action):
        if action["type"] == "attack":
            attack_roll = (
                random.randint(1, 20)
                + action["attack_bonus"]
            )
            dmg_rolls = []
            for source in action["sources"]:
              dmg_rolls.append({
                  "dmg_roll": random.randint(1, int(source["dmg_dice"])) + int(source["dmg_bonus"]),
                  "dmg_type": source["dmg_type"]
              })
            return {"type": "attack", "attack_roll": attack_roll, "dmg_roll": dmg_rolls}

    def receive_action(self, action):
        if action["type"] == "attack":
            if action["attack_roll"] >= self._ac:
                if self._status == "death_saves":
                    self._death_saves["failures"] += 2
                elif self._status == "conscious":
                    self._hp -= action["dmg_roll"]
                    self.check_status()
                    return {
                        "type": "attack",
                        "status": "hit",
                        "AC": self._ac,
                        "dmg": action["dmg_roll"],
                        "max_HP": self._hp_max,
                        "HP": self._hp,
                    }
            else:
                return {
                    "type": "attack",
                    "status": "miss",
                    "AC": self._ac,
                    "dmg": 0,
                    "max_HP": self._hp_max,
                    "HP": self._hp,
                }

    def check_status(self):
        if self._hp <= 0 and self._status == "conscious":
            self._status = "death_saves"
        elif self._hp <= 0 and self.status == "death_saves":
            death_save = random.int(1, 20)
            if death_save >= 11:
                self._death_saves["successes"] += 1
            else:
                self._death_saves["failures"] += 1
            self.check_death_saves()

    def check_death_saves(self):
        if self._death_saves["successes"] == 3:
            self._death_saves = {
                "successes": 0,
                "failures": 0
            }
            self._status = "unconscious"
            self._hp = 0
        if self._death_saves["failures"] == 3:
            self._status = "dead"

# %%
monster["actions"]
# Out:
# [{'name': 'Multiattack',
#   'multiattack_type': 'actions',
#   'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.',
#   'actions': [{'action_name': 'Frightful Presence',
#     'count': 1,
#     'type': 'ability'},
#    {'action_name': 'Bite', 'count': 1, 'type': 'melee'},
#    {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]},
#  {'name': 'Bite',
#   'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.',
#   'attack_bonus': 13,
#   'damage': [{'damage_type': {'index': 'piercing',
#      'name': 'Piercing',
#      'url': '/api/2014/damage-types/piercing'},
#     'damage_dice': '2d10+8'}],
#   'actions': []},
#  {'name': 'Claw',
#   'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.',
#   'attack_bonus': 13,
#   'damage': [{'damage_type': {'index': 'slashing',
#      'name': 'Slashing',
#      'url': '/api/2014/damage-types/slashing'},
#     'damage_dice': '2d6+8'}],
#   'actions': []},
#  {'name': 'Tail',
#   'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.',
#   'attack_bonus': 13,
#   'damage': [{'damage_type': {'index': 'bludgeoning',
#      'name': 'Bludgeoning',
#      'url': '/api/2014/damage-types/bludgeoning'},
#     'damage_dice': '2d8+8'}],
#   'actions': []},
#  {'name': 'Frightful Presence',
#   'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.",
#   'dc': {'dc_type': {'index': 'wis',
#     'name': 'WIS',
#     'url': '/api/2014/ability-scores/wis'},
#    'dc_value': 18,
#    'success_type': 'none'},
#   'actions': []},
#  {'name': 'Breath Weapons',
#   'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.',
#   'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5},
#   'options': {'choose': 1,
#    'type': 'attack',
#    'from': {'option_set_type': 'options_array',
#     'options': [{'option_type': 'breath',
#       'name': 'Cold Breath',
#       'dc': {'dc_type': {'index': 'con',
#         'name': 'CON',
#         'url': '/api/2014/ability-scores/con'},
#        'dc_value': 20,
#        'success_type': 'half'},
#       'damage': [{'damage_type': {'index': 'cold',
#          'name': 'Cold',
#          'url': '/api/2014/damage-types/cold'},
#         'damage_dice': '13d8'}]},
#      {'option_type': 'breath',
#       'name': 'Paralyzing Breath',
#       'dc': {'dc_type': {'index': 'con',
#         'name': 'CON',
#         'url': '/api/2014/ability-scores/con'},
#        'dc_value': 20,
#        'success_type': 'none'}}]}},
#   'actions': []}]

# %%
mstr = Monster(monster)
# Out:
# OG Action:	{'name': 'Multiattack', 'multiattack_type': 'actions', 'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.', 'actions': [{'action_name': 'Frightful Presence', 'count': 1, 'type': 'ability'}, {'action_name': 'Bite', 'count': 1, 'type': 'melee'}, {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]}
# MULTIATTACK
# Multi act: {'action_name': 'Frightful Presence', 'count': 1, 'type': 'ability'}
# 	{'name': 'Multiattack', 'multiattack_type': 'actions', 'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.', 'actions': [{'action_name': 'Frightful Presence', 'count': 1, 'type': 'ability'}, {'action_name': 'Bite', 'count': 1, 'type': 'melee'}, {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]}
# 	{'name': 'Bite', 'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'piercing', 'name': 'Piercing', 'url': '/api/2014/damage-types/piercing'}, 'damage_dice': '2d10+8'}], 'actions': []}
# 	{'name': 'Claw', 'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'slashing', 'name': 'Slashing', 'url': '/api/2014/damage-types/slashing'}, 'damage_dice': '2d6+8'}], 'actions': []}
# 	{'name': 'Tail', 'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'bludgeoning', 'name': 'Bludgeoning', 'url': '/api/2014/damage-types/bludgeoning'}, 'damage_dice': '2d8+8'}], 'actions': []}
# 	{'name': 'Frightful Presence', 'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.", 'dc': {'dc_type': {'index': 'wis', 'name': 'WIS', 'url': '/api/2014/ability-scores/wis'}, 'dc_value': 18, 'success_type': 'none'}, 'actions': []}
# 	{'name': 'Breath Weapons', 'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.', 'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5}, 'options': {'choose': 1, 'type': 'attack', 'from': {'option_set_type': 'options_array', 'options': [{'option_type': 'breath', 'name': 'Cold Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'half'}, 'damage': [{'damage_type': {'index': 'cold', 'name': 'Cold', 'url': '/api/2014/damage-types/cold'}, 'damage_dice': '13d8'}]}, {'option_type': 'breath', 'name': 'Paralyzing Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'none'}}]}}, 'actions': []}
# Multi act: {'action_name': 'Bite', 'count': 1, 'type': 'melee'}
# 	{'name': 'Multiattack', 'multiattack_type': 'actions', 'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.', 'actions': [{'action_name': 'Frightful Presence', 'count': 1, 'type': 'ability'}, {'action_name': 'Bite', 'count': 1, 'type': 'melee'}, {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]}
# 	{'name': 'Bite', 'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'piercing', 'name': 'Piercing', 'url': '/api/2014/damage-types/piercing'}, 'damage_dice': '2d10+8'}], 'actions': []}
# FOUND:	{'name': 'Bite', 'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'piercing', 'name': 'Piercing', 'url': '/api/2014/damage-types/piercing'}, 'damage_dice': '2d10+8'}], 'actions': []}
# 	{'name': 'Claw', 'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'slashing', 'name': 'Slashing', 'url': '/api/2014/damage-types/slashing'}, 'damage_dice': '2d6+8'}], 'actions': []}
# 	{'name': 'Tail', 'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'bludgeoning', 'name': 'Bludgeoning', 'url': '/api/2014/damage-types/bludgeoning'}, 'damage_dice': '2d8+8'}], 'actions': []}
# 	{'name': 'Frightful Presence', 'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.", 'dc': {'dc_type': {'index': 'wis', 'name': 'WIS', 'url': '/api/2014/ability-scores/wis'}, 'dc_value': 18, 'success_type': 'none'}, 'actions': []}
# 	{'name': 'Breath Weapons', 'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.', 'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5}, 'options': {'choose': 1, 'type': 'attack', 'from': {'option_set_type': 'options_array', 'options': [{'option_type': 'breath', 'name': 'Cold Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'half'}, 'damage': [{'damage_type': {'index': 'cold', 'name': 'Cold', 'url': '/api/2014/damage-types/cold'}, 'damage_dice': '13d8'}]}, {'option_type': 'breath', 'name': 'Paralyzing Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'none'}}]}}, 'actions': []}
# Multi act: {'action_name': 'Claw', 'count': 2, 'type': 'melee'}
# 	{'name': 'Multiattack', 'multiattack_type': 'actions', 'desc': 'The dragon can use its Frightful Presence. It then makes three attacks: one with its bite and two with its claws.', 'actions': [{'action_name': 'Frightful Presence', 'count': 1, 'type': 'ability'}, {'action_name': 'Bite', 'count': 1, 'type': 'melee'}, {'action_name': 'Claw', 'count': 2, 'type': 'melee'}]}
# 	{'name': 'Bite', 'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'piercing', 'name': 'Piercing', 'url': '/api/2014/damage-types/piercing'}, 'damage_dice': '2d10+8'}], 'actions': []}
# 	{'name': 'Claw', 'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'slashing', 'name': 'Slashing', 'url': '/api/2014/damage-types/slashing'}, 'damage_dice': '2d6+8'}], 'actions': []}
# FOUND:	{'name': 'Claw', 'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'slashing', 'name': 'Slashing', 'url': '/api/2014/damage-types/slashing'}, 'damage_dice': '2d6+8'}], 'actions': []}
# 	{'name': 'Tail', 'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'bludgeoning', 'name': 'Bludgeoning', 'url': '/api/2014/damage-types/bludgeoning'}, 'damage_dice': '2d8+8'}], 'actions': []}
# 	{'name': 'Frightful Presence', 'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.", 'dc': {'dc_type': {'index': 'wis', 'name': 'WIS', 'url': '/api/2014/ability-scores/wis'}, 'dc_value': 18, 'success_type': 'none'}, 'actions': []}
# 	{'name': 'Breath Weapons', 'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.', 'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5}, 'options': {'choose': 1, 'type': 'attack', 'from': {'option_set_type': 'options_array', 'options': [{'option_type': 'breath', 'name': 'Cold Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'half'}, 'damage': [{'damage_type': {'index': 'cold', 'name': 'Cold', 'url': '/api/2014/damage-types/cold'}, 'damage_dice': '13d8'}]}, {'option_type': 'breath', 'name': 'Paralyzing Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'none'}}]}}, 'actions': []}
# OG Action:	{'name': 'Bite', 'desc': 'Melee Weapon Attack: +13 to hit, reach 10 ft., one target. Hit: 19 (2d10 + 8) piercing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'piercing', 'name': 'Piercing', 'url': '/api/2014/damage-types/piercing'}, 'damage_dice': '2d10+8'}], 'actions': []}
# OG Action:	{'name': 'Claw', 'desc': 'Melee Weapon Attack: +13 to hit, reach 5 ft., one target. Hit: 15 (2d6 + 8) slashing damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'slashing', 'name': 'Slashing', 'url': '/api/2014/damage-types/slashing'}, 'damage_dice': '2d6+8'}], 'actions': []}
# OG Action:	{'name': 'Tail', 'desc': 'Melee Weapon Attack: +13 to hit, reach 15 ft., one target. Hit: 17 (2d8 + 8) bludgeoning damage.', 'attack_bonus': 13, 'damage': [{'damage_type': {'index': 'bludgeoning', 'name': 'Bludgeoning', 'url': '/api/2014/damage-types/bludgeoning'}, 'damage_dice': '2d8+8'}], 'actions': []}
# OG Action:	{'name': 'Frightful Presence', 'desc': "Each creature of the dragon's choice that is within 120 feet of the dragon and aware of it must succeed on a DC 18 Wisdom saving throw or become frightened for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature's saving throw is successful or the effect ends for it, the creature is immune to the dragon's Frightful Presence for the next 24 hours.", 'dc': {'dc_type': {'index': 'wis', 'name': 'WIS', 'url': '/api/2014/ability-scores/wis'}, 'dc_value': 18, 'success_type': 'none'}, 'actions': []}
# OG Action:	{'name': 'Breath Weapons', 'desc': 'The dragon uses one of the following breath weapons.\nCold Breath. The dragon exhales an icy blast in a 60-foot cone. Each creature in that area must make a DC 20 Constitution saving throw, taking 58 (13d8) cold damage on a failed save, or half as much damage on a successful one.\nParalyzing Breath. The dragon exhales paralyzing gas in a 60-foot cone. Each creature in that area must succeed on a DC 20 Constitution saving throw or be paralyzed for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success.', 'usage': {'type': 'recharge on roll', 'dice': '1d6', 'min_value': 5}, 'options': {'choose': 1, 'type': 'attack', 'from': {'option_set_type': 'options_array', 'options': [{'option_type': 'breath', 'name': 'Cold Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'half'}, 'damage': [{'damage_type': {'index': 'cold', 'name': 'Cold', 'url': '/api/2014/damage-types/cold'}, 'damage_dice': '13d8'}]}, {'option_type': 'breath', 'name': 'Paralyzing Breath', 'dc': {'dc_type': {'index': 'con', 'name': 'CON', 'url': '/api/2014/ability-scores/con'}, 'dc_value': 20, 'success_type': 'none'}}]}}, 'actions': []}

# %%
print(mstr._modifiers)
print(mstr._proficiencies)
print(mstr._actions)
# Out:
# {'STR': 8, 'DEX': 0, 'CON': 7, 'INT': 3, 'WIS': 1, 'CHA': 5}
# {'saving_throws': [{'stat': 'DEX', 'value': 5}, {'stat': 'CON', 'value': 12}, {'stat': 'WIS', 'value': 6}, {'stat': 'CHA', 'value': 10}], 'skills': [{'skill': 'Arcana', 'value': 8}, {'skill': 'History', 'value': 8}, {'skill': 'Perception', 'value': 11}, {'skill': 'Stealth', 'value': 5}]}
# [{'name': 'Multiattack', 'type': 'attack', 'attacks': [{'attack_bonus': 13, 'sources': [{'dmg_type': 'Piercing', 'dmg_dice': '10', 'dmg_bonus': '8'}]}, {'attack_bonus': 13, 'sources': [{'dmg_type': 'Slashing', 'dmg_dice': '6', 'dmg_bonus': '8'}]}, {'attack_bonus': 13, 'sources': [{'dmg_type': 'Slashing', 'dmg_dice': '6', 'dmg_bonus': '8'}]}]}, {'name': 'Tail', 'type': 'attack', 'attacks': [{'attack_bonus': 13, 'sources': [{'dmg_type': 'Bludgeoning', 'dmg_dice': '8', 'dmg_bonus': '8'}]}]}, {'name': 'Frightful Presence', 'type': 'dc', 'dc_stat': 'WIS', 'dc_value': 18}, {'name': 'Breath Weapons', 'type': 'attack', 'attack_type': 'usage'}]

# %%
mstr._actions
# Out:
# [{'name': 'Multiattack',
#   'type': 'attack',
#   'attacks': [{'attack_bonus': 13,
#     'sources': [{'dmg_type': 'Piercing', 'dmg_dice': '10', 'dmg_bonus': '8'}]},
#    {'attack_bonus': 13,
#     'sources': [{'dmg_type': 'Slashing', 'dmg_dice': '6', 'dmg_bonus': '8'}]},
#    {'attack_bonus': 13,
#     'sources': [{'dmg_type': 'Slashing',
#       'dmg_dice': '6',
#       'dmg_bonus': '8'}]}]},
#  {'name': 'Tail',
#   'type': 'attack',
#   'attacks': [{'attack_bonus': 13,
#     'sources': [{'dmg_type': 'Bludgeoning',
#       'dmg_dice': '8',
#       'dmg_bonus': '8'}]}]},
#  {'name': 'Frightful Presence',
#   'type': 'dc',
#   'dc_stat': 'WIS',
#   'dc_value': 18},
#  {'name': 'Breath Weapons', 'type': 'attack', 'attack_type': 'usage'}]
